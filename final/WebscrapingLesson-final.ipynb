# %% [markdown]
# # Webscraping with Python

# %% [markdown]
# ## Introduction
# This session will introduce web scraping with Python. Along the way we will discuss how web pages are structured and how information is passed from a web browser to a web site.

# %% [markdown]
# ## Part I
# We'll begin by loading some essential web scraping modules into our Python environment:
# - [Requests](http://docs.python-requests.org/en/master/)
# - [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Re](https://docs.python.org/3/library/re.html)
# - [Time](https://docs.python.org/3.6/library/time.html#module-time)

# %%
# import our modules - if you're using Anaconda, these should all be bundled
import requests
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# ### 1.1 Basics
# This first example uses [AFL-CIO Legislative Alerts](http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts) site which contains a chronological inventory of official communications sent by the organiztion to legislators.

# %%
# make our first GET request
req = requests.get("http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts")

# %%
type(req)
src = req.text
src
# Out:
# '<!DOCTYPE html>\n<html xmlns:fb="http://ogp.me/ns/fb#" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" class="no-js"> \n<head>    \n  \n\n\t \n\t                             \n    <title>\tLegislative Alerts\t</title>\n\n    \n    \n                <meta name="Content-Type" content="text/html; charset=utf-8" />\n\n            <meta name="Content-language" content="en-US" />\n\n                                                      \n                <meta name="author" content="" />\n    \n                <meta name="copyright" content="" />\n    \n                <meta name="description" content="" />\n    \n                <meta name="keywords" content="" />\n    \n        <meta name="MSSmartTagsPreventParsing" content="TRUE" />\n    <meta name="generator" content="eZ Publish" />\n\t\n\t\n\t\t\t<meta property="og:title" content="Legislative Alerts" />\n<meta property="og:url" content="http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts" />\n<meta property="og:site_name" content="AFL-CIO" /><meta property="og:image" content="http://www.aflcio.org/extension/aflcio/design/aflcio_user/images/facebook_aflcio_200x200.jpg" />\t\n<meta property="og:type" content="non_profit" />\n<meta property="fb:app_id" content="288636237825618" />\n\t<meta property="og:description" content="Visit the AFL-CIO for the latest updates, including news, videos and information on how you take action and get involved in your community." />\n    \n<link rel="Home" href="/" title="AFL-CIO front page" />\n<link rel="Index" href="/" />\n<link rel="Top"  href="/" title="\tLegislative Alerts\t" />\n<link rel="Search" href="/content/advancedsearch" title="Search AFL-CIO" />\n<link rel="Shortcut icon" href="/extension/aflcio/design/aflcio_user/images/favicon.ico" type="image/x-icon" />\n<link rel="Copyright" href="/ezinfo/copyright" />\n<link rel="Author" href="/ezinfo/about" />\n  \n\n<script src="/extension/aflcio/design/aflcio_user/javascript/libs/modernizr-2.0.6.min.js"></script> \n\n\n\n\t<script src="//cdn.optimizely.com/js/167440347.js"></script>\n\n<script src="/extension/aflcio/design/aflcio_user/javascript/jquery-1.8.3.min.js"></script>      <link rel="stylesheet" type="text/css" href="/var/ezflow_site/cache/public/stylesheets/ff286538b6fee0d729f3bf965568bde4_all.css" />\r\n\n<link rel="stylesheet" type="text/css" href="/var/storage/packages/eZ-systems/ezflow_design/files/default/file/classes-colors.css" />\n<link rel="stylesheet" type="text/css" href="/var/storage/packages/eZ-systems/ezflow_design/files/default/file/site-colors.css" />\n<link rel="stylesheet" type="text/css" href="/extension/aflcio/design/aflcio_user/stylesheets/print.css" media="print" />\n<!-- IE conditional comments; for bug fixes for different IE versions -->\n<!--[if IE 5]>     <style type="text/css"> @import url(/extension/ezflow/design/ezflow/stylesheets/browsers/ie5.css);    </style> <![endif]-->\n<!--[if lte IE 7]> <style type="text/css"> @import url(/extension/ezflow/design/ezflow/stylesheets/browsers/ie7lte.css); </style> <![endif]--> \n<!--[if IE]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie.css" rel="stylesheet"  media="all" /><![endif]-->\n<!--[if IE 7]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie7.css" rel="stylesheet" media="all" /><![endif]-->\n<!--[if IE 8]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie8.css" rel="stylesheet" media="all" /><![endif]-->\n<!-- <link href="/extension/aflcio/design/aflcio_user/stylesheets/print.css" rel="stylesheet" media="print" /> print already called TDA -->\n\n\n<link rel="stylesheet" href="/extension/aflcio/design/aflcio_user/stylesheets/superfish.css" media="screen">\n\n\n\n\t\n\t\t\t\t\n\t\t<!--Analytics script starts here-->\n\t\t<script src="/extension/aflcio/design/aflcio_user/javascript/ga_link_tracker_async.js" type="text/javascript"></script>\n\t\t<script type="text/javascript">\n\t\t\tvar _gaq = _gaq || [];\n\t\t\t\n\t\t\t\t// Use correct ...

# %%
type(src)
# Out:
# str

# %% [markdown]
# In order to make sense of this data we'll need to learn more about how web pages are structured.

# %% [markdown]
# ### 1.2 HTML structure

# %% [markdown]
# ![HTML <>](https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/HTML5_de_Erick_Dimas.jpg/800px-HTML5_de_Erick_Dimas.jpg)
#
# It's impossible to scrape web sites without knowing something about HTML markup. Because we have limited time, this tutorial will focus on only a small subset of the language. Here's some basic terminology I'll use repeatedly.
# - __Elements__
# - __Tags__
# - __Attributes__
# - __Content__
#
# __*Elements*__ are defined by a starting *tag* and the text within the element is the __*content*__.
#
# Examples:
# ```html
# <p> This is a paragraph </p>
# <h1> This is a heading </h1>
# <div> This is a division </div>
# ```
# __*Elements*__ can also be nested
# ```html
# <p> This is a paragraph with <b>bold</b> text</p>
# ```
#
# __*Attributes*__ provide additional information about an element.
#
# ```html
# <div class="intro">This is division contains the introduction</div>
# ```
#
# - *div* is the tag name.
# - *class* is the attribute name.
# - *intro* is the attribute value.
#
# We'll dig a little more deeply into HTML after looking again at the Project Gutenberg web site.

# %% [markdown]
# ### 1.3 Exploring page structure with Chrome
# Let's look again at the [Legislative Alerts](http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts) page and explore it's HTML elements.
# - Right-click (or Ctrl-click on a Mac) on the text "Election 2016" near the top left of the page.
# - Look at the panel that opens on the right side (or possibly bottom) of your screen and answer these questions.
# 1. What tag is the text contained in?
# 2. In what tag is that one embedded?
# 3. What other tags are embedded with it?
#
# A powerful feature of Chrome inspect is the ability to identify *sets* of elements. Shortly, we'll learn how important this is to effective scraping. One way to do this to hover your mouse over individual items in the panel and see what gets higlighted on the page. Another, more powerful is to assign new attributes to a tag. Let's try that with the *li* tag and add a background color.
# - Inspect any legislative alert title in the main body of the page.
# - Select one of the sets of ```<div>``` elements in the main inspect panel.
# - Click the '+' sign in the lower left panel
# - A new ```<div>``` item will appear in the lower left panel.
# - Click within the curly braces then enter "background-color" or select it from the list that appears and hit enter.
# - Choose a color from the list and hit enter again.
#
# Now let's use this information to scrape some content from the page.

# %% [markdown]
# ## Part 2
# ### 2.1 Making soup
# Beautiful Soup is a popular Python module for navigating and searching through scraped web content. Here's a simple example.

# %%
# Getting started with Beautiful Soup
soup = BeautifulSoup(src, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Legislative Alerts
#   </title>
#   <meta content="text/html; charset=utf-8" name="Content-Type"/>
#   <meta content="en-US" name="Content-language"/>
#   <meta content="" name="author"/>
#   <meta content="" name="copyright"/>
#   <meta content="" name="description"/>
#   <meta content="" name="keywords"/>
#   <meta content="TRUE" name="MSSmartTagsPreventParsing"/>
#   <meta content="eZ Publish" name="generator"/>
#   <meta content="Legislative Alerts" property="og:title"/>
#   <meta content="http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts" property="og:url"/>
#   <meta content="AFL-CIO" property="og:site_name"/>
#   <meta content="http://www.aflcio.org/extension/aflcio/design/aflcio_user/images/facebook_aflcio_200x200.jpg" property="og:image"/>
#   <meta content="non_profit" property="og:type"/>
#   <meta content="288636237825618" property="fb:app_id"/>
#   <meta content="Visit the AFL-CIO for the latest updates, including news, videos and information on how you take action and get involved in your community." property="og:description"/>
#   <link href="/" rel="Home" title="AFL-CIO front page"/>
#   <link href="/" rel="Index"/>
#   <link href="/" rel="Top" title="	Legislative Alerts	"/>
#   <link href="/content/advancedsearch" rel="Search" title="Search AFL-CIO"/>
#   <link href="/extension/aflcio/design/aflcio_user/images/favicon.ico" rel="Shortcut icon" type="image/x-icon"/>
#   <link href="/ezinfo/copyright" rel="Copyright"/>
#   <link href="/ezinfo/about" rel="Author"/>
#   <script src="/extension/aflcio/design/aflcio_user/javascript/libs/modernizr-2.0.6.min.js">
#   </script>
#   <script src="//cdn.optimizely.com/js/167440347.js">
#   </script>
#   <script src="/extension/aflcio/design/aflcio_user/javascript/jquery-1.8.3.min.js">
#   </script>
#   <link href="/var/ezflow_site/cache/public/stylesheets/ff286538b6fee0d729f3bf965568bde4_all.css" rel="stylesheet" type="text/css"/>
#   <link href="/var/storage/packages/eZ-systems/ezflow_design/files/default/file/classes-colors.css" rel="stylesheet" type="text/css"/>
#   <link href="/var/storage/packages/eZ-systems/ezflow_design/files/default/file/site-colors.css" rel="stylesheet" type="text/css"/>
#   <link href="/extension/aflcio/design/aflcio_user/stylesheets/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <!-- IE conditional comments; for bug fixes for different IE versions -->
#   <!--[if IE 5]>     <style type="text/css"> @import url(/extension/ezflow/design/ezflow/stylesheets/browsers/ie5.css);    </style> <![endif]-->
#   <!--[if lte IE 7]> <style type="text/css"> @import url(/extension/ezflow/design/ezflow/stylesheets/browsers/ie7lte.css); </style> <![endif]-->
#   <!--[if IE]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie.css" rel="stylesheet"  media="all" /><![endif]-->
#   <!--[if IE 7]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie7.css" rel="stylesheet" media="all" /><![endif]-->
#   <!--[if IE 8]><link href="/extension/aflcio/design/aflcio_user/stylesheets/ie8.css" rel="stylesheet" media="all" /><![endif]-->
#   <!-- <link href="/extension/aflcio/design/aflcio_user/stylesheets/print.css" rel="stylesheet" media="print" /> print already called TDA -->
#   <link href="/extension/aflcio/design/aflcio_user/stylesheets/superfish.css" media="screen" rel="stylesheet"/>
#   <!--Analytics script starts here-->
#   <script src="/extension/aflcio/design/aflcio_user/javascript/ga_link_tracker_async.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#
# 				// Use correct UA code
# 			_gaq.push(['_setAccount', 'UA-762017-26']);
#
# 				// Decide how to track. (These are not mutually exclusive.)
# 			var trackEvents = true;
# 			var trackPageViews = false;
#
# 				// regular expressions matching the domain, make sure to list them from most specific to least specific
# 			var trackedDomains = [
# 				/^https?:\/\/([\w_\.-]*aflcio\.org)\/?/
# 				,/^https?:\/\/([\w_\.-]*workingamerica\.org)\/?/
# 			];
#
# 				// End configuration
# 			bf.onLoad(bf.ga.trackLinks, null, trackedDomains, trackEvents, trackPageViews);
# 			bf.ga.configureGA();
# 			_gaq.push(['_trackPageview']);
#
# 			(function() {			var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 			ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 			var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 			})();
#   </script>
#   <!--Analytics Script ends here-->
#   <script type="text/javascript">
#    if (document.referrer.match(/google\./gi)) {
#         var myString = document.referrer;
#         var r        = myString.match(/cd=(.*?)&/);
#         var rank     = parseInt(r[1]);
#         var kw       = myString.match(/q=(.*?)&/);
#
#       if (kw[1].length > 0) {
#         var keyWord  = decodeURI(kw[1]);
#       } else {
#         keyWord = "(not provided)";
#       }
#
#       var p        = document.location.pathname;
#       _gaq.push(['_trackEvent', 'RankTracker', keyWord, p, rank, true]);
#       }
#   </script>
#  </head>
#  <body class="ui-navigation" id="node-196">
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) {return;}
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/all.js#xfbml=1&appId=288636237825618";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <div id="ada508">
#    <strong>
#     Shortcut Navigation:
#    </strong>
#    <ul>
#     <li>
#      <a accesskey="p" href="#content" title="Skip to page content">
#       Page Content
#      </a>
#     </li>
#     <li>
#      <a accesskey="n" href="#topNav" title="Skip to main navigation menu">
#       Site Navigation
#      </a>
#     </li>
#     <li>
#      <a accesskey="s" href="#search" title="Skip to search">
#       Search
#      </a>
#     </li>
#     <li>
#      <a accesskey="f" href="#footer" title="Skip to footer (ctrl/alt + f)">
#       Footer
#      </a>
#     </li>
#    </ul>
#   </div>
#   <!-- #ada508 shortcuts -->
#   <script charset="utf-8" src="/var/ezflow_site/cache/public/javascript/6aff7cb43b2ae32ace696ac3c4a50742.js" type="text/javascript">
#   </script>
#   <style id="ezste-main-css" type="text/css">
#    body
# {
# }
#   </style>
#   <div id="header">
#    <header>
#     <h1 class="logo">
#      <a href="/" title="">
#       <img alt="" class="logo" height="" src="/extension/aflcio/design/aflcio_user/images/logo.png" width=""/>
#      </a>
#     </h1>
#     <nav>
#      <ul id="quickLinks">
#       <li class="view-listitem listitem-nav_itemqnav-action-center">
#        <a href="/Get-Involved/Action-Center">
#         Action Center
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_itemqnav-joinWorkingAmerica">
#        <a href="http://www.workingamerica.org/join/">
#         Join Working America
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_itemqnav-pressRoom">
#        <a href="/Press-Room">
#         Press Room
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_itemqnav-enEspanol">
#        <a href="/En-Espanol">
#         En Español
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_itemqnav-election2016">
#        <a href="http://www.workingamericavotes.org">
#         Election 2016
#        </a>
#       </li>
#       <li>
#        <form action="/content/search/" id="siteSearch" method="get">
#         <label for="keyword">
#          Search:
#         </label>
#         <input id="keyword" name="SearchText" title="Put phrases in quotes." type="text"/>
#         <input alt="search" class="button" src="/extension/aflcio/design/aflcio_user/images/icn-magnifier.png" type="image"/>
#        </form>
#       </li>
#      </ul>
#     </nav>
#     <nav>
#      <ul class="sf-menu" id="mainNav">
#       <li class="tnav-getInvolved off">
#        <a href="/Get-Involved">
#         GET INVOLVED
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Voting.-For-a-Better-Life" title="Labor Day 2016">
#             Labor Day 2016
#            </a>
#           </li>
#           <li class="view-listitem listitem-action_center">
#            <a href="/Get-Involved/Action-Center" title="Action Center">
#             Action Center
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Find-a-State-or-Local-AFL-CIO" title="Find a State or Local AFL-CIO">
#             Find a State or Local AFL-CIO
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Join-Working-America" title="Join Working America">
#             Join Working America
#            </a>
#           </li>
#           <li class="view-listitem listitem-landing_page">
#            <a href="/Get-Involved/Young-Workers" title="Young Workers">
#             Young Workers
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Become-a-Union-Organizer" title="Become a Union Organizer">
#             Become a Union Organizer
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Union-Summer2" title="Union Summer">
#             Union Summer
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Law-Student-Union-Summer" title="Law Student Union Summer 2016">
#             Law Student Union Summer 2016
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/The-Bonnie-Ladin-Union-Skills-Training-Program" title="The Bonnie Ladin Union Skills Training Program">
#             The Bonnie Ladin Union Skills Training Program
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Buttons-and-Banners" title="Buttons and Banners">
#             Buttons and Banners
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/AFL-CIO-Endorsed-Boycotts" title="AFL-CIO-Endorsed Boycotts">
#             AFL-CIO-Endorsed Boycotts
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/Thank-a-Worker" title="Thank a Worker">
#             Thank a Worker
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Get-Involved/The-Union-Shop" title="The Union Shop">
#             The Union Shop
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-learnAboutUnions off">
#        <a href="/Learn-About-Unions">
#         LEARN ABOUT UNIONS
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/What-Unions-Do" title="What Unions Do">
#             What Unions Do
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/atWork" title="Our Values @Work">
#             Our Values @Work
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/How-to-Join-or-Form-a-Union" title="How to Join or Form a Union">
#             How to Join or Form a Union
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/Collective-Bargaining" title="Collective Bargaining">
#             Collective Bargaining
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/Training-and-Apprenticeships" title="Training and Apprenticeships">
#             Training and Apprenticeships
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/Global-Labor-Movement" title="Global Labor Movement">
#             Global Labor Movement
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/Faith-and-Labor" title="Faith and Labor">
#             Faith and Labor
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Learn-About-Unions/Member-Benefits" title="Member Benefits">
#             Member Benefits
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-issues off">
#        <a href="/Issues">
#         ISSUES
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Jobs-and-Economy" title="Jobs and Economy">
#             Jobs and Economy
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Health-Care" title="Health Care">
#             Health Care
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Retirement-Security" title="Retirement Security">
#             Retirement Security
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Work-and-Family" title="Work and Family">
#             Work and Family
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Trade" title="Trade">
#             Trade
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/education" title="Education">
#             Education
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Civil-and-Workplace-Rights" title="Civil and Workplace Rights">
#             Civil and Workplace Rights
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Immigration" title="Immigration">
#             Immigration
#            </a>
#           </li>
#           <li class="view-listitem listitem-issue_landing">
#            <a href="/Issues/Job-Safety" title="Job Safety">
#             Job Safety
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-legislationPolitics on">
#        <a href="/Legislation-and-Politics">
#         LEGISLATION &amp; POLITICS
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-link">
#            <a href="/Legislation-and-Politics/Election-2016" title="Election 2016">
#             Election 2016
#            </a>
#           </li>
#           <li class="view-listitem listitem-link">
#            <a href="/Legislation-and-Politics/My-Vote-My-Right2" title="My Vote My Right">
#             My Vote My Right
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Legislation-and-Politics/State-Legislative-Battles" title="State Legislative Battles">
#             State Legislative Battles
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Legislation-and-Politics/Legislative-Voting-Records" title="Legislative Voting Records">
#             Legislative Voting Records
#            </a>
#           </li>
#           <li class="view-listitem listitem-listing_page">
#            <a href="/Legislation-and-Politics/Legislative-Alerts" title="Legislative Alerts">
#             Legislative Alerts
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Legislation-and-Politics/Legislative-Handbook" title="Legislative Handbook">
#             Legislative Handbook
#            </a>
#           </li>
#           <li class="view-listitem listitem-listing_page">
#            <a href="/Legislation-and-Politics/Testimonies" title="Testimonies">
#             Testimonies
#            </a>
#           </li>
#           <li class="view-listitem listitem-community_landing">
#            <a href="/Legislation-and-Politics/Your-Elected-Officials" title="Your Elected Officials">
#             Your Elected Officials
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-corporateWatch off">
#        <a href="/Corporate-Watch">
#         CORPORATE WATCH
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Paywatch-2016" title="Executive Paywatch">
#             Executive Paywatch
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Capital-Stewardship" title="Capital Stewardship">
#             Capital Stewardship
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Avoiding-Their-Fair-Share-of-Taxes" title="Avoiding Their Fair Share of Taxes">
#             Avoiding Their Fair Share of Taxes
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Research-Resources" title="Research Resources">
#             Research Resources
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Government-Service-Golden-Parachutes" title="Government Service Golden Parachutes">
#             Government Service Golden Parachutes
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/Corporate-Watch/Why-Shareholder-Reforms-Are-Vital-for-All-Working-People" title="Why Shareholder Reforms Are Vital for All Working People">
#             Why Shareholder Reforms Are Vital for All Working People
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-aboutAFLCIO off">
#        <a href="/About">
#         ABOUT AFL-CIO
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Our-Mission-and-Vision" title="Our Mission and Vision">
#             Our Mission and Vision
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Find-a-State-or-Local-AFL-CIO" title="Find a State or Local AFL-CIO">
#             Find a State or Local AFL-CIO
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Digital-Strategies-Trainings" title="Digital Strategies Trainings">
#             Digital Strategies Trainings
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/What-the-AFL-CIO-Does" title="What the AFL-CIO Does">
#             What the AFL-CIO Does
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Leadership" title="Leadership">
#             Leadership
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/AFL-CIO-Unions" title="AFL-CIO Unions">
#             AFL-CIO Unions
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Common-Sense-Economics" title="Common Sense Economics">
#             Common Sense Economics
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Community-Services" title="Community Services">
#             Community Services
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Worker-Center-Partnerships" title="Worker Center Partnerships">
#             Worker Center Partnerships
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Allied-Organizations" title="Allied Organizations">
#             Allied Organizations
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Global-Unions" title="Global Unions">
#             Global Unions
#            </a>
#           </li>
#           <li class="view-listitem listitem-landing_page">
#            <a href="/About/Our-History" title="Our History">
#             Our History
#            </a>
#           </li>
#           <li class="view-listitem listitem-landing_page">
#            <a href="/About/Exec-Council" title="Executive Council and Conventions">
#             Executive Council and Conventions
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Member-Benefits" title="Member Benefits">
#             Member Benefits
#            </a>
#           </li>
#           <li class="view-listitem listitem-content_page">
#            <a href="/About/Jobs-at-the-AFL-CIO" title="Jobs at the AFL-CIO">
#             Jobs at the AFL-CIO
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="tnav-aflcioNowBlog off">
#        <a href="/Blog">
#         AFL-CIO NOW BLOG
#        </a>
#        <ul class="superPanel">
#         <li class="navGroup">
#          <ul>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Economy" title="Economy">
#             Economy
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Community-Services" title="Community Services">
#             Community Services
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/In-The-States" title="In The States">
#             In The States
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Organizing-Bargaining" title="Organizing/Bargaining">
#             Organizing/Bargaining
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Political-Action-Legislation" title="Political Action/Legislation">
#             Political Action/Legislation
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Training" title="Training and Apprenticeships">
#             Training and Apprenticeships
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Your-Turn" title="Your Turn">
#             Your Turn
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Corporate-Greed" title="Corporate Greed">
#             Corporate Greed
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Global-Action" title="Global Action">
#             Global Action
#            </a>
#           </li>
#           <li class="view-listitem listitem-blog_channel">
#            <a href="/Blog/Other-News" title="Other News">
#             Other News
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </nav>
#    </header>
#   </div>
#   <!-- header -->
#   <div class="layout-leftCenter layout-subpage clearfix" id="layout">
#    <div class="sidebarOne">
#     <nav>
#      <ul id="subNav">
#       <!-- start : 82 -->
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/Election-2016">
#         Election 2016
#        </a>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/My-Vote-My-Right2">
#         My Vote My Right
#        </a>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/State-Legislative-Battles">
#         State Legislative Battles
#        </a>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/Legislative-Voting-Records">
#         Legislative Voting Records
#        </a>
#       </li>
#       <!-- descend -->
#       <li class="on">
#        <span class="icon">
#        </span>
#        <span class="Legislative Alerts">
#         <a href="/Legislation-and-Politics/Legislative-Alerts">
#          Legislative Alerts
#         </a>
#        </span>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/Legislative-Handbook">
#         Legislative Handbook
#        </a>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/Testimonies">
#         Testimonies
#        </a>
#       </li>
#       <!-- item -->
#       <li class="view-nav_item ">
#        <a href="/Legislation-and-Politics/Your-Elected-Officials">
#         Your Elected Officials
#        </a>
#       </li>
#      </ul>
#      <!-- /subNav -->
#     </nav>
#     <!-- sectionzone START: -->
#     <!-- 196 -->
#     <!-- folder 64731 -->
#     <!-- left left index=0 -->
#     <div id="address-e580846ae418b3cd2868c3660fd00b4e-ecf874621af8d55376da4be7bab01210">
#      <iframe border="0" class="atWork" frameborder="0" height="361" scrolling="no" src="http://www.aflcio.org/atWork/(widget)" width="100%">
#      </iframe>
#      <style type="text/css">
#       .sidebarOne iframe.atWork, .sidebarTwo iframe.atWork{overflow:hidden;margin-top:.5em}
# 		div.layout-leftCenterRight .sidebarTwo iframe.atWork{margin-left:4px;}
#      </style>
#     </div>
#     <!-- sectionzone END: -->
#    </div>
#    <div class="pageHolder clearfix">
#     <div class="breadcrumb">
#      <!-- node breadcrumb -->
#      <a href="/">
#       Home
#      </a>
#      &gt;
#      <a href="/Legislation-and-Politics">
#       Legislation and Politics
#      </a>
#      &gt;
#      <span>
#       Legislative Alerts
#      </span>
#     </div>
#     <!-- sectionzone START: -->
#     <!-- 196 -->
#     <!-- folder 64731 -->
#     <!-- sectionzone END: -->
#     <section class="content-view-full full-listing_page">
#      <header>
#       <!-- inside node/view/full -->
#       <div class="page-title">
#        <h1>
#         Legislative Alerts
#        </h1>
#       </div>
#      </header>
#      <div class="legisalerts_searchtool" style="margin-top: 0px;">
#       <div class="search legisalerts_search">
#        <form action="/Legislation-and-Politics/Legislative-Alerts/" id="siteSearch" method="post">
#         <label for="keyword">
#          Search Legislative Alerts:
#         </label>
#         <input id="keyword" name="SearchText" size="10" type="text" value=""/>
#         <input alt="search" class="button" src="/extension/aflcio/design/aflcio_user/images/btn-search-blog.png" type="image"/>
#         <span>
#         </span>
#        </form>
#       </div>
#       <div class="legisalerts_year_search">
#        <!-- //navigation footer -->
#        <form>
#         <label for="children_years_EC">
#          Browse by Year:
#         </label>
#         <select id="children_years">
#          <option selected="selected" value="2016">
#           2016
#          </option>
#          <option value="2015">
#           2015
#          </option>
#          <option value="2014">
#           2014
#          </option>
#          <option value="2013">
#           2013
#          </option>
#          <option value="2012">
#           2012
#          </option>
#          <option value="2011">
#           2011
#          </option>
#          <option value="2010">
#           2010
#          </option>
#         </select>
#        </form>
#        <script type="text/javascript">
#         $(document).ready(function(){
# 					$('#children_years').change(function(){
# 						window.location = "/Legislation-and-Politics/Legislative-Alerts/(y)/"+$(this).val();
# 					});
# 				});
#        </script>
#       </div>
#      </div>
#      <div class="legisalerts_listing">
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act">
#          Letter to Senators in Support of the Water Resources Development Act
#         </a>
#        </div>
#        <div id="legalert_date">
#         September 14, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-legislation-that-would-rob-millions-of-workers-of-overtime-pay-protection">
#          Letter to Representatives in opposition to legislation that would rob millions of workers of overtime pay protection.
#         </a>
#        </div>
#        <div id="legalert_date">
#         July 15, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-in-Support-of-Barack-Obama-s-Veto-of-DOL-Retirement-Rule-Override">
#          Letter in Support of Barack Obama's Veto of DOL Retirement Rule Override
#         </a>
#        </div>
#        <div id="legalert_date">
#         June 21, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Myths-v-Facts-Response-ILRWG-H-2B-Approps-FY-2017">
#          Myths v Facts Response - ILRWG H-2B Approps FY 2017
#         </a>
#        </div>
#        <div id="legalert_date">
#         June 13, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/AFL-CIO-Opposes-H-2B-Returning-Worker-Amendment">
#          AFL-CIO Opposes H-2B  Returning Worker Amendment
#         </a>
#        </div>
#        <div id="legalert_date">
#         June 13, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-House-Education-and-the-Workforce-Committee-Urging-Them-to-Oppose-the-Resolution-to-Block-the-Dept.-of-Labor-s-Persuader-Rule">
#          Letter to House Education and the Workforce Committee Urging Them to Oppose the Resolution to Block the Dept. of Labor's Persuader Rule
#         </a>
#        </div>
#        <div id="legalert_date">
#         May 17, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-the-Local-Radio-Freedom-Act">
#          Letter to Representatives in opposition to the Local Radio Freedom Act
#         </a>
#        </div>
#        <div id="legalert_date">
#         February 19, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-opposition-to-the-Local-Radio-Freedom-Act">
#          Letter to Senators in opposition to the Local Radio Freedom Act
#         </a>
#        </div>
#        <div id="legalert_date">
#         February 19, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-oppose-the-conference-report-on-the-Customs-Bill-H.R.-644">
#          Letter to Senators urging them to oppose the conference report on the Customs Bill (H.R. 644)
#         </a>
#        </div>
#        <div id="legalert_date">
#         February 09, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-Workplace-Action-for-a-Growing-Economy-Act">
#          Letter to Senators in support of the Workplace Action for a Growing Economy Act
#         </a>
#        </div>
#        <div id="legalert_date">
#         January 07, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-The-Workplace-Action-for-a-Growing-Economy-Act">
#          Letter to Representatives in support of The Workplace Action for a Growing Economy Act
#         </a>
#        </div>
#        <div id="legalert_date">
#         January 07, 2016
#        </div>
#       </div>
#       <div class="ec_statements">
#        <div id="legalert_title">
#         <a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-opposing-the-Fairness-in-Class-Action-Litigation-and-Furthering-Asbestos-Claim-Transparency-Act">
#          Letter to Representatives opposing the "Fairness in Class Action Litigation and Furthering Asbestos Claim Transparency Act"
#         </a>
#        </div>
#        <div id="legalert_date">
#         January 05, 2016
#        </div>
#       </div>
#      </div>
#     </section>
#     <!-- //full-legislative_alert -->
#     <!-- sectionzone START: -->
#     <!-- 196 -->
#     <!-- folder 64731 -->
#     <!-- sectionzone END: -->
#    </div>
#    <!-- /pageHolder -->
#   </div>
#   <!-- /layout-leftCenter -->
#   <div id="footerHolder">
#    <div class="pageHolder social_banner joinUsOnline">
#     <ul>
#      <li>
#       <a href="http://www.flickr.com/photos/afl-cio/" target="_blank">
#        <img alt="Flickr" height="24" src="/extension/aflcio/design/aflcio_user/images/icn-flickr24.png" width="24"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.youtube.com/user/AFLCIONow" target="_blank">
#        <img alt="YouTube" height="24" src="/extension/aflcio/design/aflcio_user/images/icn-youtube24.png" width="24"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://twitter.com/AFLCIO" target="_blank">
#        <img alt="Twitter" height="24" src="/extension/aflcio/design/aflcio_user/images/icn-twitter24.png" width="24"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.facebook.com/aflcio" target="_blank">
#        <img alt="Facebook" height="24" src="/extension/aflcio/design/aflcio_user/images/icn-facebook24.png" width="24"/>
#       </a>
#      </li>
#     </ul>
#     <h2>
#      Join Us Online
#     </h2>
#    </div>
#    <section class="pageHolder linkSet">
#     <article class="mod">
#      <h2>
#       <a href="/Learn-About-Unions">
#        Learn About Unions
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/Learn-About-Unions/What-Unions-Do" target="_self">
#         What Unions Do
#        </a>
#       </li>
#       <li>
#        <a href="/Learn-About-Unions/How-to-Join-or-Form-a-Union" target="_self">
#         Join or Form a Union
#        </a>
#       </li>
#       <li>
#        <a href="/Get-Involved/Become-a-Union-Organizer" target="_self">
#         Become an Organizer
#        </a>
#       </li>
#       <li>
#        <a href="/Learn-About-Unions/Global-Labor-Movement" target="_self">
#         The International Labor Movement
#        </a>
#       </li>
#      </ul>
#     </article>
#     <!-- mod -->
#     <article class="mod">
#      <h2>
#       <a href="/Legislation-and-Politics">
#        Legislation &amp; Politics
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/In-Your-Community" target="_self">
#         Your Elected Officials
#        </a>
#       </li>
#       <li>
#        <a href="/Legislation-and-Politics/Legislative-Voting-Records" target="_self">
#         Legislative Voting Records
#        </a>
#       </li>
#       <li>
#        <a href="/Legislation-and-Politics/Election-2012" target="_self">
#         Political Action
#        </a>
#       </li>
#       <li>
#        <a href="http://myvotemyright.org" target="_self">
#         Voters' Rights
#        </a>
#       </li>
#      </ul>
#     </article>
#     <!-- mod -->
#     <article class="mod">
#      <h2>
#       <a href="/About">
#        About AFL-CIO
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/About/Our-Mission-and-Vision" target="_self">
#         Our Mission &amp; Vision
#        </a>
#       </li>
#       <li>
#        <a href="/About/What-the-AFL-CIO-Does" target="_self">
#         What AFL-CIO Does
#        </a>
#       </li>
#       <li>
#        <a href="/About/AFL-CIO-Unions" target="_self">
#         Our Unions
#        </a>
#       </li>
#       <li>
#        <a href="/About/Exec-Council" target="_self">
#         Executive Council &amp; Convention Actions
#        </a>
#       </li>
#      </ul>
#     </article>
#     <!-- mod -->
#     <article class="mod">
#      <h2>
#       <a href="/Newsletter-Signup">
#        Connect With Us
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/In-Your-Community" target="_self">
#         In Your Community
#        </a>
#       </li>
#       <li>
#        <a href="/Newsletter-Signup" target="_self">
#         Sign Up for E-Mails
#        </a>
#       </li>
#       <li>
#        <a href="/rss/feed/Blog" target="_self">
#         AFL-CIO Now RSS
#        </a>
#       </li>
#      </ul>
#     </article>
#     <!-- mod -->
#    </section>
#    <script src="/extension/aflcio/design/aflcio_user/javascript/libs/jquery.jcarousel.min.js">
#    </script>
#    <script>
#     jQuery(document).ready(function() {
# 			jQuery('#adScroller').jcarousel({
# 				wrap: 'circular'
# 			});
# 		});
#    </script>
#    <div class="pageHolder footerAds">
#     <div id="adScroller">
#      <ul>
#       <li>
#        <a href="/Get-Involved/Young-Workers">
#         <img alt="Next UP" height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/next-up/2405421-1-eng-US/Next-UP_adbuttonwide.png" style="border: 0px  ;" title="Next UP" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href=" http://www.unionplus.org/new-improved-credit-card">
#         <img alt="Union Plus Credit Card" height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/union-plus-credit-card/2400081-1-eng-US/Union-Plus-Credit-Card_adbuttonwide.gif" style="border: 0px  ;" title="Union Plus Credit Card" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="http://workingamericahealthcare.org/">
#         <img alt="Working America Health Care" height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/working-america-health-care/2405501-2-eng-US/Working-America-Health-Care_adbuttonwide.jpg" style="border: 0px  ;" title="Working America Health Care" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="http://www.laborheritage.org/">
#         <img alt="Labor Heritage Foundation" height="70" src="/var/ezflow_site/storage/images/aflcio/site-settings/footer-promos/labor-heritage-foundation/683-5-eng-US/Labor-Heritage-Foundation_adbuttonwide.jpg" style="border: 0px  ;" title="Labor Heritage Foundation" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="http://www.theunionbootpro.com/aflciousa.cfm">
#         <img alt="The Union Boot Pro Ad" height="70" src="/var/ezflow_site/storage/images/aflcio/site-settings/footer-promos/the-union-boot-pro/73209-1-eng-US/The-Union-Boot-Pro_adbuttonwide.jpg" style="border: 0px  ;" title="The Union Boot Pro Ad" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="http://www.unionsportsmen.org/">
#         <img alt="Union Sportsmen's Alliance Ad" height="70" src="/var/ezflow_site/storage/images/aflcio/site-settings/footer-promos/union-sportsmen-s-alliance/72869-1-eng-US/Union-Sportsmen-s-Alliance_adbuttonwide.jpg" style="border: 0px  ;" title="Union Sportsmen's Alliance Ad" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.aflcioefcu.org/index.html">
#         <img alt="AFL-CIO Credit Union" height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/afl-cio-credit-union/2608001-1-eng-US/AFL-CIO-Credit-Union_adbuttonwide.png" style="border: 0px  ;" title="AFL-CIO Credit Union" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="www.unionveterans.org">
#         <img alt="Union Veterans Council" height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/union-veterans-council/718-1-eng-US/Union-Veterans-Council_adbuttonwide.gif" style="border: 0px  ;" title="Union Veterans Council" width="180"/>
#        </a>
#       </li>
#       <li>
#        <a href="/About/Stronger-Together">
#         <img alt="We're Stronger Together. Join us today." height="70" src="/var/ezflow_site/storage/images/site_aflcio/site-settings/footer-promos/we-re-stronger-together/2890731-1-eng-US/We-re-Stronger-Together_adbuttonwide.jpg" style="border: 0px  ;" title="We're Stronger Together. Join us today." width="180"/>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="pageHolder footer">
#     <address class="address">
#     </address>
#     <p class="copyright">
#      Copyright © 2016 AFL-CIO
#     </p>
#     <nav>
#      <ul class="links">
#       <li class="view-listitem listitem-nav_item">
#        <a href="/Contact-Us">
#         Contact Us
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_item">
#        <a href="/Multimedia">
#         Multimedia
#        </a>
#        |
#       </li>
#       <li class="view-listitem listitem-nav_itemlast">
#        <a href="/Privacy-Policy-and-Terms-of-Use">
#         Privacy Policy &amp; Terms of Use
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div class="text_msg-text">
#      Text
#      <strong>
#       WORK
#      </strong>
#      to
#      <strong>
#       235246
#      </strong>
#      to receive periodic text alerts from the AFL-CIO (message and data rates may apply).
#     </div>
#    </div>
#    <!-- footer -->
#   </div>
#   <!-- footerHolder -->
#   <script type="text/javascript">
#    var switchTo5x=true;
#   </script>
#   <script src="/extension/aflcio/design/aflcio_user/javascript/libs/superfish.js">
#   </script>
#   <script src="/extension/aflcio/design/aflcio_user/javascript/libs/hoverIntent.min.js">
#   </script>
#   <script>
#    // initialise main nav
# 	jQuery(function(){
# 		jQuery('ul.sf-menu').superfish({
# 		delay: 400,// the delay before sub closes
# 		autoArrows	: false,
# 		speed: 'fast'// speed of the fade-in
# 		});
# 	});
#   </script>
#   <!--img src="http://ad.retargeter.com/seg?add=593437&t=2" width="1" height="1" /-->
#   <script type="text/javascript">
#    adroll_adv_id = "RLG6ULEEQND7LE72CNIE2R";
# adroll_pix_id = "RO7HYXBXEZA2XOYH2UXGI4";
# (function () {
# var oldonload = window.onload;
# window.onload = function(){
#    __adroll_loaded=true;
#    var scr = document.createElement("script");
#    var host = (("https:" == document.location.protocol) ? "https://s.adroll.com" : "http://a.adroll.com");
#    scr.setAttribute('async', 'true');
#    scr.type = "text/javascript";
#    scr.src = host + "/j/roundtrip.js";
#    ((document.getElementsByTagName('head') || [null])[0] ||
#     document.getElementsByTagName('script')[0].parentNode).appendChild(scr);
#    if(oldonload){oldonload()}};
# }());
#   </script>
#   <script type="text/javascript">
#    var axel = Math.random() + "";
# var a = axel * 10000000000000;
# document.write('<iframe src="https://4552251.fls.doubleclick.net/activityi;src=4552251;type=partn0;cat=wahc_002;ord=1;num=' + a + '?" width="1" height="1" frameborder="0" style="display:none"></iframe>');
#   </script>
#   <noscript>
#    <iframe frameborder="0" height="1" src="https://4552251.fls.doubleclick.net/activityi;src=4552251;type=partn0;cat=wahc_002;ord=1;num=1?" style="display:none" width="1">
#    </iframe>
#   </noscript>
#   <!-- End of DoubleClick Floodlight Tag: Please do not remove -->
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var google_conversion_id = 1007743207;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1007743207/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <iframe frameborder="0" height="0" name="IB5k Tracking - AFL CIO MAIN PAGE" scrolling="no" src="//insight.adsrvr.org/tags/pt2fwhm/kekfpuz6/iframe" width="0">
#   </iframe>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "url": "https://www.aflcio.org/",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.aflcio.org/content/search/?SearchText={search_term}&x=0&y=0",
#     "query-input": "required name=search_term"
#   }
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### 2.2 Find page elements
# Beautiful Soup provides functions that allow searching a page by tags and attributes. Let's look again at the elements in the Top 100 page and determine how to identify the list of titles. We can then use the find_all function to retrieve them.

# %%
# Find elements
alerts = soup("div", class_="ec_statements")
print (type(alerts[0]))
first_alert = alerts[0]
print(first_alert)
# Out:
# <class 'bs4.element.Tag'>
# <div class="ec_statements">
# <div id="legalert_title"><a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act">Letter to Senators in Support of the Water Resources Development Act</a></div>
# <div id="legalert_date">September 14, 2016</div>
# </div>

# %%
print(first_alert.text)
# Out:
# Letter to Senators in Support of the Water Resources Development Act
# September 14, 2016

# %% [markdown]
# Because first_title is a Tag element, it has a text property.

# %%
# Print some content
first_alert.select('div#legalert_title ')
# Out:
# [<div id="legalert_title"><a href="/Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act">Letter to Senators in Support of the Water Resources Development Act</a></div>]

# %% [markdown]
# This text is obviously much cleaner than what we started with, but we still need to do some more work to parse it out and make it more actionable.

# %% [markdown]
# ### 2.3 Using selectors
# Beautiful Soup structures page content in a tree structure and provides functions that allow searching based on relationships between tags.

# %%
# Review

# %%
first_title = first_alert.select('div#legalert_title a')
type(first_title)
len(first_title)
type(first_title[0])
first_title[0].text
# Out:
# 'Letter to Senators in Support of the Water Resources Development Act'

# %% [markdown]
# These results are closer to what we need, but still need more cleanup. The solution lies in using more specific selectors.

# %%
# Selector examples
alert = alerts[0]
title = alert.select('div#legalert_title a')
print(type(title))
print(title[0]['href'])
for i in range(len(title)):
    print(title[i]['href'])
# Out:
# <class 'list'>
# /Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act
# /Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act

# %%
date = alert.select('div#legalert_date')
print(date[0].text)
# Out:
# September 14, 2016

# %% [markdown]
# Now that we understand the structure, we can start thinking about how to access the data in our code. It's also critical to remember the following:
# - *Tag* objects have a text property. This is how to retrieve *clean* content.
# - When the tag has an attribute, the attribute value can be retrieved using the bracket notation.

# %%
# Figure out what objects are returned and how to use them

# %% [markdown]
# Note that the link is only a portion of the url. In order to use this, we'll need to append it to a base url.

# %%
# Fix the urls
print("http://www.aflcio.org/"+title[0]['href'])
# Out:
# http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act

# %% [markdown]
# ### 2.4 Iteration
# Typically, scraping involves pulling multiple pieces of content from a page. Because BeautifulSoup creates iterable structures out of page contents, it's easy to use standard Python list constructs to extract data.

# %%
# Extract all the titles and links and dates from all the alerts (start by copying and pasting the code above)
# Use a dict structure to capture the different elements
base_url = "http://www.aflcio.org/"
alerts = soup.find_all('div', class_ = "ec_statements")
results = []
for alert in alerts:
    item = {}
    title = alert.select('div#legalert_title a')
    date = alert.select('div#legalert_date')
    item['title'] = title[0].text
    item['url'] = base_url + title[0]['href']
    item['date'] = date[0].text
    results.append(item)

# %%
results
# Out:
# [{'date': 'September 14, 2016',
#   'title': 'Letter to Senators in Support of the Water Resources Development Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-Support-of-the-Water-Resources-Development-Act'},
#  {'date': 'July 15, 2016',
#   'title': 'Letter to Representatives in opposition to legislation that would rob millions of workers of overtime pay protection.',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-legislation-that-would-rob-millions-of-workers-of-overtime-pay-protection'},
#  {'date': 'June 21, 2016',
#   'title': "Letter in Support of Barack Obama's Veto of DOL Retirement Rule Override",
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-in-Support-of-Barack-Obama-s-Veto-of-DOL-Retirement-Rule-Override'},
#  {'date': 'June 13, 2016',
#   'title': 'Myths v Facts Response - ILRWG H-2B Approps FY 2017',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Myths-v-Facts-Response-ILRWG-H-2B-Approps-FY-2017'},
#  {'date': 'June 13, 2016',
#   'title': 'AFL-CIO Opposes H-2B  Returning Worker Amendment',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/AFL-CIO-Opposes-H-2B-Returning-Worker-Amendment'},
#  {'date': 'May 17, 2016',
#   'title': "Letter to House Education and the Workforce Committee Urging Them to Oppose the Resolution to Block the Dept. of Labor's Persuader Rule",
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-House-Education-and-the-Workforce-Committee-Urging-Them-to-Oppose-the-Resolution-to-Block-the-Dept.-of-Labor-s-Persuader-Rule'},
#  {'date': 'February 19, 2016',
#   'title': 'Letter to Representatives in opposition to the Local Radio Freedom Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-the-Local-Radio-Freedom-Act'},
#  {'date': 'February 19, 2016',
#   'title': 'Letter to Senators in opposition to the Local Radio Freedom Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-opposition-to-the-Local-Radio-Freedom-Act'},
#  {'date': 'February 09, 2016',
#   'title': 'Letter to Senators urging them to oppose the conference report on the Customs Bill (H.R. 644)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-oppose-the-conference-report-on-the-Customs-Bill-H.R.-644'},
#  {'date': 'January 07, 2016',
#   'title': 'Letter to Senators in support of the Workplace Action for a Growing Economy Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-Workplace-Action-for-a-Growing-Economy-Act'},
#  {'date': 'January 07, 2016',
#   'title': 'Letter to Representatives in support of The Workplace Action for a Growing Economy Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-The-Workplace-Action-for-a-Growing-Economy-Act'},
#  {'date': 'January 05, 2016',
#   'title': 'Letter to Representatives opposing the "Fairness in Class Action Litigation and Furthering Asbestos Claim Transparency Act"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-opposing-the-Fairness-in-Class-Action-Litigation-and-Furthering-Asbestos-Claim-Transparency-Act'}]

# %% [markdown]
# ## Part 3
# ### 3.1 Multi-step scraping
# What if we want to download the actual text of, say, the top 10, titles on the list. We'll need to do the following.
# 1. Find the particular list we want to scrape
# 2. Gather the links to the download page
# 3. Use those links to fetch the contents of the download page.
# 4. Choose the appropriate link for retrieving the text we need.
# 5. Save the text to a file.

# %% [markdown]
# ### 3.2 Using functions
# Functions are a useful approach to organizing the different parsing stages of a mult-step scrape. We'll write two functions for this example. One will retrieve a list of links for a given list *year*. The other will retrieve the text of the letter.

# %%
def get_alerts(year):
    ## you'll need to look at the how the site url changes to figure out how to handle the year parameter
    
    alerts_url = "http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts/(y)/" + str(year)
    req = requests.get(alerts_url)
    src = req.text
    soup = BeautifulSoup(src)
    
    base_url = "http://www.aflcio.org/"
    alerts = soup.find_all('div', class_ = "ec_statements")
    results = []
    for alert in alerts:
        item = {}
        title = alert.select('div#legalert_title a')
        date = alert.select('div#legalert_date')
        item['title'] = title[0].text
        item['url'] = base_url + title[0]['href']
        item['date'] = date[0].text
        results.append(item)
    return(results)

# %%
get_alerts(2015)
# Out:
# /Users/RK/anaconda/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [{'date': 'December 17, 2015',
#   'title': 'Letter to Representatives expressing views on the Consolidated Appropriations Act of 2016',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-expressing-views-on-the-Consolidated-Appropriations-Act-of-2016'},
#  {'date': 'December 03, 2015',
#   'title': "Letter to Representatives urging them to support the Fixing America's Surface Transportation (FAST) Act (H.R. 22)",
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-support-the-Fixing-America-s-Surface-Transportation-FAST-Act-H.R.-22'},
#  {'date': 'November 30, 2015',
#   'title': 'Letter to Sens. Grassley and Durbin in support of the H-1B and L-1 Visa Reform Act of 2015 (S. 2266)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Sens.-Grassley-and-Durbin-in-support-of-the-H-1B-and-L-1-Visa-Reform-Act-of-2015-S.-2266'},
#  {'date': 'November 19, 2015',
#   'title': 'Letter to Representatives urging them to vote against the American SAFE Act of 2015 (H.R. 4038)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-the-American-SAFE-Act-of-2015-H.R.-4038'},
#  {'date': 'November 04, 2015',
#   'title': 'Letter to Representatives supporting the Surface Transportation Reauthorization and Reform Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-supporting-the-Surface-Transportation-Reauthorization-and-Reform-Act'},
#  {'date': 'October 27, 2015',
#   'title': 'Letter to Representatives urging them to oppose the "Protecting Local Business Opportunity Act"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-oppose-the-Protecting-Local-Business-Opportunity-Act'},
#  {'date': 'October 27, 2015',
#   'title': 'Letter to Representatives urging them to reauthorize the Export-Import Bank',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-reauthorize-the-Export-Import-Bank'},
#  {'date': 'October 22, 2015',
#   'title': "Letter to Representatives urging opposition to the Restoring Americans' Healthcare Freedom Reconciliation Act",
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-opposition-to-the-Restoring-Americans-Healthcare-Freedom-Reconciliation-Act'},
#  {'date': 'October 22, 2015',
#   'title': 'Letter to Representatives urging opposition to the misnamed Retail Investor Protection Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-opposition-to-the-misnamed-Retail-Investor-Protection-Act'},
#  {'date': 'October 21, 2015',
#   'title': 'Letter to House Transportation Committee commending its efforts in crafting the Surface Transportation Reauthorization and Reform Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-House-Transportation-Committee-commending-its-efforts-in-crafting-the-Surface-Transportation-Reauthorization-and-Reform-Act'},
#  {'date': 'September 30, 2015',
#   'title': 'Letter to Representatives in support of The Social Security Earned Payment Act of 2015',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-The-Social-Security-Earned-Payment-Act-of-2015'},
#  {'date': 'September 30, 2015',
#   'title': 'Letter to Senators in support of The Social Security Earned Payment Act of 2015',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-The-Social-Security-Earned-Payment-Act-of-2015'},
#  {'date': 'September 30, 2015',
#   'title': 'Letter to House Financial Services Committee urging them to oppose the misnamed "Retail Investor Protection Act"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-House-Financial-Services-Committee-urging-them-to-oppose-the-misnamed-Retail-Investor-Protection-Act'},
#  {'date': 'September 28, 2015',
#   'title': 'Letter to Representatives urging them to support the Workplace Action for a Growing Economy Act (WAGE Act)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-support-the-Workplace-Action-for-a-Growing-Economy-Act-WAGE-Act'},
#  {'date': 'September 28, 2015',
#   'title': 'Letter to Senators in support of the Workplace Action for a Growing Economy Act (WAGE Act)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-Workplace-Action-for-a-Growing-Economy-Act-WAGE-Act'},
#  {'date': 'September 14, 2015',
#   'title': 'Letter to Senators in support of the James Zadroga 9/11 Health and Compensation Reauthorization',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-James-Zadroga-9-11-Health-and-Compensation-Reauthorization'},
#  {'date': 'September 14, 2015',
#   'title': 'Letter to Representatives in support of the James Zadroga 9/11 Health and Compensation Reauthorization Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-the-James-Zadroga-9-11-Health-and-Compensation-Reauthorization-Act'},
#  {'date': 'July 29, 2015',
#   'title': 'Letter to Representatives urging them to oppose H.R. 1994 and the Wenstrup substitute amendment',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-oppose-H.R.-1994-and-the-Wenstrup-substitute-amendment'},
#  {'date': 'July 27, 2015',
#   'title': 'Letter to Representatives in opposition to H.R. 427, the Regulations from the Executive in Need of Scrutiny Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-H.R.-427-the-Regulations-from-the-Executive-in-Need-of-Scrutiny-Act'},
#  {'date': 'July 22, 2015',
#   'title': "Letter to the Senate Committee on Veterans' Affairs opposing Senator Rubio's  S. 1082",
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-the-Senate-Committee-on-Veterans-Affairs-opposing-Senator-Rubio-s-S.-1082'},
#  {'date': 'June 25, 2015',
#   'title': 'Letter to Senate Appropriations Committee expressing concern about the inadequate allocations in the 2016 Labor-HHS Appropriations bill',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senate-Appropriations-Committee-expressing-concern-about-the-inadequate-allocations-in-the-2016-Labor-HHS-Appropriations-bill'},
#  {'date': 'June 24, 2015',
#   'title': 'Letter to the House Committee on Veterans’ Affairs urging them to oppose H.R. 1994',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-the-House-Committee-on-Veterans-Affairs-urging-them-to-oppose-H.R.-1994'},
#  {'date': 'June 23, 2015',
#   'title': 'Letter to Senators urging them to support legislation to implement a financial transaction tax.',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-support-legislation-to-implement-a-financial-transaction-tax'},
#  {'date': 'June 23, 2015',
#   'title': 'Letter to Representatives urging them to support legislation to implement a financial transaction tax.',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-support-legislation-to-implement-a-financial-transaction-tax'},
#  {'date': 'June 22, 2015',
#   'title': 'Letter to Senators urging them to oppose the Fast Track 2015 legislation',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-oppose-the-Fast-Track-2015-legislation'},
#  {'date': 'June 17, 2015',
#   'title': 'Letter to House Appropriations Committee opposing the 2016 Labor-HHS Appropriations bill',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-House-Appropriations-Committee-opposing-the-2016-Labor-HHS-Appropriations-bill'},
#  {'date': 'June 10, 2015',
#   'title': 'Letter to Senators urging them to support the following National Defense Authorization Act amendments',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-support-the-following-National-Defense-Authorization-Act-amendments'},
#  {'date': 'June 10, 2015',
#   'title': 'Letter to Representatives urging them to vote against the Trade Adjustment Assistance proposal',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-the-Trade-Adjustment-Assistance-proposal'},
#  {'date': 'June 04, 2015',
#   'title': 'Letter to Representatives urging them to oppose the Tribal Labor Sovereignty Act (H.R. 511)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-oppose-the-Tribal-Labor-Sovereignty-Act-H.R.-511'},
#  {'date': 'June 03, 2015',
#   'title': 'Letter to the Senate Committee on Indian Affairs urging them to vote against the Tribal Labor Sovereignty Act (S. 248)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-the-Senate-Committee-on-Indian-Affairs-urging-them-to-vote-against-the-Tribal-Labor-Sovereignty-Act-S.-248'},
#  {'date': 'May 22, 2015',
#   'title': 'Letter to Senators in support of the bipartisan Portman-Stabenow amendment on currency (S.A. 1299)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-bipartisan-Portman-Stabenow-amendment-on-currency-S.A.-1299'},
#  {'date': 'May 20, 2015',
#   'title': 'Letter to the Senate Banking Committee in opposition to the draft legislation, "The Financial Regulatory Improvement Act of 2015"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-the-Senate-Banking-Committee-in-opposition-to-the-draft-legislation-The-Financial-Regulatory-Improvement-Act-of-2015'},
#  {'date': 'May 05, 2015',
#   'title': 'Letter to Senators Johnson and Carper urging them to oppose the Arizona Borderlands Protection and Preservation Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-Johnson-and-Carper-urging-them-to-oppose-the-Arizona-Borderlands-Protection-and-Preservation-Act'},
#  {'date': 'April 29, 2015',
#   'title': 'Letter to Representatives in opposition of the Smith Amendment of H.R. 2029',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-of-the-Smith-Amendment-of-H.R.-2029'},
#  {'date': 'April 28, 2015',
#   'title': 'Letter to Representatives urging them to support workforce management accountability amendments to the 2016 National Defense Authorization Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-support-workforce-management-accountability-amendments-to-the-2016-National-Defense-Authorization-Act'},
#  {'date': 'April 23, 2015',
#   'title': 'Letter to Representatives urging them to oppose the “Fast Track 2015” legislation and support the alternative "Right Track for TPP Act of 2015"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-oppose-the-Fast-Track-2015-legislation-and-support-the-alternative-Right-Track-for-TPP-Act-of-2015'},
#  {'date': 'April 22, 2015',
#   'title': 'Letter to Senators urging them to oppose "Fast Track 2015" legislation',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-oppose-Fast-Track-2015-legislation'},
#  {'date': 'April 15, 2015',
#   'title': 'Letter to Representatives urging them to oppose H.R. 1090, the misnamed “Retail Investor Protection Act,”',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-oppose-H.R.-1090-the-misnamed-Retail-Investor-Protection-Act'},
#  {'date': 'April 14, 2015',
#   'title': 'Letter to Representatives in support of the Paycheck Fairness Act of 2015 (H.R. 1619)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-the-Paycheck-Fairness-Act-of-2015-H.R.-1619'},
#  {'date': 'April 14, 2015',
#   'title': 'Letter to Senators in support of the Paycheck Fairness Act of 2015 (S.862)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-in-support-of-the-Paycheck-Fairness-Act-of-2015-S.862'},
#  {'date': 'April 13, 2015',
#   'title': 'Letter to Representatives in support of the "Fair Play Fair Pay Act"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-the-Fair-Play-Fair-Pay-Act'},
#  {'date': 'March 26, 2015',
#   'title': 'Letter to Senators urging them to vote against the Senate 2016 Budget Resolution',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-vote-against-the-Senate-2016-Budget-Resolution'},
#  {'date': 'March 24, 2015',
#   'title': 'Letter to Representatives urging them to vote against the reckless House 2016 Budget Resolution (H Con Res. 27)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-the-reckless-House-2016-Budget-Resolution-H-Con-Res.-27'},
#  {'date': 'March 16, 2015',
#   'title': 'Letter to Senators urging the swift confirmation of Loretta E. Lynch as Attorney General',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-the-swift-confirmation-of-Loretta-E.-Lynch-as-Attorney-General'},
#  {'date': 'March 13, 2015',
#   'title': 'Letter to Representatives urging them to vote against H.J. Res 29, a resolution of disapproval of the NLRB election rules',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-H.J.-Res-29-a-resolution-of-disapproval-of-the-NLRB-election-rules'},
#  {'date': 'March 02, 2015',
#   'title': 'Letter to Senators and Representatives asking them to oppose "fast track" trade promotion authority',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-and-Representatives-asking-them-to-oppose-fast-track-trade-promotion-authority'},
#  {'date': 'February 26, 2015',
#   'title': 'Letter to Representatives in opposition to the undermining Student Success Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-the-undermining-Student-Success-Act'},
#  {'date': 'February 25, 2015',
#   'title': 'Letter to Senators urging them to vote against the callous and anti-immigrant "Immigration Rule of Law Act of 2015"',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-vote-against-the-callous-and-anti-immigrant-Immigration-Rule-of-Law-Act-of-2015'},
#  {'date': 'February 23, 2015',
#   'title': 'Letter to Senate Judiciary Committee urging the swift confirmation of Loretta Lynch',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senate-Judiciary-Committee-urging-the-swift-confirmation-of-Loretta-Lynch'},
#  {'date': 'February 03, 2015',
#   'title': 'Letter to Representatives expressing opposition to H.R. 526, the "Furthering Asbestos Claim Transparency Act',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-expressing-opposition-to-H.R.-526-the-Furthering-Asbestos-Claim-Transparency-Act'},
#  {'date': 'February 03, 2015',
#   'title': 'Letter to Representatives expressing opposition to H.R. 50 and H.R. 527',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-expressing-opposition-to-H.R.-50-and-H.R.-527'},
#  {'date': 'February 02, 2015',
#   'title': 'Letter to Senators urging them to pass a clean funding bill for the Department of Homeland Security',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-to-pass-a-clean-funding-bill-for-the-Department-of-Homeland-Security'},
#  {'date': 'February 02, 2015',
#   'title': 'Letter to Representatives urging them to vote against H.R. 596, legislation that will repeal ACA',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-H.R.-596-legislation-that-will-repeal-ACA'},
#  {'date': 'January 20, 2015',
#   'title': 'Letter to Senators urging them not to co-sponsor the Immigration Innovation Act of 2015 (S. 153)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Senators-urging-them-not-to-co-sponsor-the-Immigration-Innovation-Act-of-2015-S.-153'},
#  {'date': 'January 13, 2015',
#   'title': 'Letter to Representatives in opposition to H.R. 185, the Regulatory Accountability Act of 2015',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-H.R.-185-the-Regulatory-Accountability-Act-of-2015'},
#  {'date': 'January 13, 2015',
#   'title': 'Letter to Representatives in support of a clean funding bill for the Department of Homeland Security and to vote no on harmful immigration amendments',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-support-of-a-clean-funding-bill-for-the-Department-of-Homeland-Security-and-to-vote-no-on-harmful-immigration-amendments'},
#  {'date': 'January 13, 2015',
#   'title': 'Letter to Representatives in opposition to the “Promoting Job Creation and Reducing Small Business Burdens Act” (H.R. 37)',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-in-opposition-to-the-Promoting-Job-Creation-and-Reducing-Small-Business-Burdens-Act-H.R.-37'},
#  {'date': 'January 06, 2015',
#   'title': 'Letter to Representatives urging them to vote against the misnamed Save American Workers Act.',
#   'url': 'http://www.aflcio.org//Legislation-and-Politics/Legislative-Alerts/Letter-to-Representatives-urging-them-to-vote-against-the-misnamed-Save-American-Workers-Act'}]

# %%
links = get_alerts(2015)
# Out:
# /Users/RK/anaconda/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
for i in range(len(links)):
    print (links[i]['title'])
# Out:
# Letter to Representatives expressing views on the Consolidated Appropriations Act of 2016
# Letter to Representatives urging them to support the Fixing America's Surface Transportation (FAST) Act (H.R. 22)
# Letter to Sens. Grassley and Durbin in support of the H-1B and L-1 Visa Reform Act of 2015 (S. 2266)
# Letter to Representatives urging them to vote against the American SAFE Act of 2015 (H.R. 4038)
# Letter to Representatives supporting the Surface Transportation Reauthorization and Reform Act
# Letter to Representatives urging them to oppose the "Protecting Local Business Opportunity Act"
# Letter to Representatives urging them to reauthorize the Export-Import Bank
# Letter to Representatives urging opposition to the Restoring Americans' Healthcare Freedom Reconciliation Act
# Letter to Representatives urging opposition to the misnamed Retail Investor Protection Act
# Letter to House Transportation Committee commending its efforts in crafting the Surface Transportation Reauthorization and Reform Act
# Letter to Representatives in support of The Social Security Earned Payment Act of 2015
# Letter to Senators in support of The Social Security Earned Payment Act of 2015
# Letter to House Financial Services Committee urging them to oppose the misnamed "Retail Investor Protection Act"
# Letter to Representatives urging them to support the Workplace Action for a Growing Economy Act (WAGE Act)
# Letter to Senators in support of the Workplace Action for a Growing Economy Act (WAGE Act)
# Letter to Senators in support of the James Zadroga 9/11 Health and Compensation Reauthorization
# Letter to Representatives in support of the James Zadroga 9/11 Health and Compensation Reauthorization Act
# Letter to Representatives urging them to oppose H.R. 1994 and the Wenstrup substitute amendment
# Letter to Representatives in opposition to H.R. 427, the Regulations from the Executive in Need of Scrutiny Act
# Letter to the Senate Committee on Veterans' Affairs opposing Senator Rubio's  S. 1082
# Letter to Senate Appropriations Committee expressing concern about the inadequate allocations in the 2016 Labor-HHS Appropriations bill
# Letter to the House Committee on Veterans’ Affairs urging them to oppose H.R. 1994
# Letter to Senators urging them to support legislation to implement a financial transaction tax.
# Letter to Representatives urging them to support legislation to implement a financial transaction tax.
# Letter to Senators urging them to oppose the Fast Track 2015 legislation
# Letter to House Appropriations Committee opposing the 2016 Labor-HHS Appropriations bill
# Letter to Senators urging them to support the following National Defense Authorization Act amendments
# Letter to Representatives urging them to vote against the Trade Adjustment Assistance proposal
# Letter to Representatives urging them to oppose the Tribal Labor Sovereignty Act (H.R. 511)
# Letter to the Senate Committee on Indian Affairs urging them to vote against the Tribal Labor Sovereignty Act (S. 248)
# Letter to Senators in support of the bipartisan Portman-Stabenow amendment on currency (S.A. 1299)
# Letter to the Senate Banking Committee in opposition to the draft legislation, "The Financial Regulatory Improvement Act of 2015"
# Letter to Senators Johnson and Carper urging them to oppose the Arizona Borderlands Protection and Preservation Act
# Letter to Representatives in opposition of the Smith Amendment of H.R. 2029
# Letter to Representatives urging them to support workforce management accountability amendments to the 2016 National Defense Authorization Act
# Letter to Representatives urging them to oppose the “Fast Track 2015” legislation and support the alternative "Right Track for TPP Act of 2015"
# Letter to Senators urging them to oppose "Fast Track 2015" legislation
# Letter to Representatives urging them to oppose H.R. 1090, the misnamed “Retail Investor Protection Act,”
# Letter to Representatives in support of the Paycheck Fairness Act of 2015 (H.R. 1619)
# Letter to Senators in support of the Paycheck Fairness Act of 2015 (S.862)
# Letter to Representatives in support of the "Fair Play Fair Pay Act"
# Letter to Senators urging them to vote against the Senate 2016 Budget Resolution
# Letter to Representatives urging them to vote against the reckless House 2016 Budget Resolution (H Con Res. 27)
# Letter to Senators urging the swift confirmation of Loretta E. Lynch as Attorney General
# Letter to Representatives urging them to vote against H.J. Res 29, a resolution of disapproval of the NLRB election rules
# Letter to Senators and Representatives asking them to oppose "fast track" trade promotion authority
# Letter to Representatives in opposition to the undermining Student Success Act
# Letter to Senators urging them to vote against the callous and anti-immigrant "Immigration Rule of Law Act of 2015"
# Letter to Senate Judiciary Committee urging the swift confirmation of Loretta Lynch
# Letter to Representatives expressing opposition to H.R. 526, the "Furthering Asbestos Claim Transparency Act
# Letter to Representatives expressing opposition to H.R. 50 and H.R. 527
# Letter to Senators urging them to pass a clean funding bill for the Department of Homeland Security
# Letter to Representatives urging them to vote against H.R. 596, legislation that will repeal ACA
# Letter to Senators urging them not to co-sponsor the Immigration Innovation Act of 2015 (S. 153)
# Letter to Representatives in opposition to H.R. 185, the Regulatory Accountability Act of 2015
# Letter to Representatives in support of a clean funding bill for the Department of Homeland Security and to vote no on harmful immigration amendments
# Letter to Representatives in opposition to the “Promoting Job Creation and Reducing Small Business Burdens Act” (H.R. 37)
# Letter to Representatives urging them to vote against the misnamed Save American Workers Act.

# %%
# move this code to the get_letter function

def get_letter(url):
    ## insert code
    req = requests.get(url)
    src = req.text
    soup = BeautifulSoup(src, 'lxml')
    body = soup('div', class_ =  "attribute-body")
    text = body[0].text

    return(text)

# %%
# Try this
links = get_alerts("2015")
print(get_letter(links[5]['url']))
# Out:
# Dear Representative:On behalf of the AFL-CIO, a federation of 56 national and international unions representing more than 12 million working men and women across the United States, I am writing to urge you to oppose H.R. 3459, the “Protecting Local Business Opportunity Act.”H.R. 3459 overturns the National Labor Relations Board’s (NLRB) recent decision in Browning-Ferris Industries (August 27, 2015) and substitutes a confusing and restrictive test for finding two employers to be “joint employers” under the National Labor Relations Act. The legislation is misguided and will undermine the ability of workers to speak up together for higher wages and better working conditions.In Browning-Ferris¸ the NLRB decided that its previous decisions had taken an overly narrow view of the joint employer issue, resulting in situations where workers could not join together for improved employment conditions. Browning-Ferris contracted with a staffing agency—Leadpoint Business Solutions—to supply workers for its recycling operation. The company established the line speed, staffing levels, and shift times, and set a cap on pay. The NLRB found that, under these circumstances, Browning-Ferris was—with Leadpoint—a joint employer of workers supplied to Browning-Ferris by Leadpoint. The decision means that the Leadpoint workers at Browning-Ferris will have the opportunity to join together to demand better working conditions from the entity that holds the real economic power—Browning-Ferris.As the employment relationship becomes more fractured and companies continue to contract with staffing agencies and other suppliers for personnel, it is essential that our workplace laws keep pace with these changes and ensure the protection of workers’ rights. The Browning-Ferris decision affirmed and strengthened the NLRB’s longstanding joint employer test by adjusting it to the realities of today’s workplaces. Congress should applaud the decision— not overturn it.H.R. 3459 overturns the Browning Ferris decision and substitutes a requirement that two employers can only be considered joint employers if each employer “shares and exercises control over essential terms and conditions of employment and such control over these matters is actual, direct, and immediate.” In other words, Browning-Ferris could avoid being a joint employer with the staffing agency. It could deny Leadpoint workers the opportunity to demand better employment conditions by maintaining an on-site Leadpoint supervisor who would act as a buffer between Browning-Ferris and Leadpoint workers—even if Browning-Ferris continued to hold the economic power in the workplace. This legal maneuvering and manipulation to deny workers’ rights is exactly the type of practice we should try to avoid. But H.R. 3459 would encourage and incentivize the practice, weakening the power of working people at the time they need it the most.The NLRB’s recent decision in Browning-Ferris Industries accurately took a broader view of joint employer relationships—substituting a test that the “Protecting Local Business Opportunity Act” would overturn. For this reason, I urge you to oppose H.R. 3459.Sincerely,
# William Samuel, DirectorGovernment Affairs Department
# /Users/RK/anaconda/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# ### 3.3 Tying it all together

# %% [markdown]
# ## Part 4
# We've examined relatively straightforward scraping examples. Here are a few pointers on some more advanced scraping scenarios you are likely to eventually encounter.
# ### 4.1 Advance text cleaning
# Regular expressions often play an important role in webscraping. We don't have enough time to fully cover the topic so let's look at one practical application using the site we've been scraping. Imagine we need to capture the numeric data in the lists, i.e. the actual number of downloads. We can use a regular expression to parse out the clean title and the count. Here's an example from another website - https://www.gutenberg.org/browse/scores/top

# %%
###
full_title = "Pride and Prejudice by Jane Austen (1340)"
m = re.search(r'(.+)\s\((\d+)\)', full_title)
details = {}
if m:
    details['all'] = m.group(0)
    details['title'] = m.group(1)
    details['count'] = m.group(2)
print(details)
print(details['all'])
print(details['title'])
print(details['count'])
# Out:
# {'title': 'Pride and Prejudice by Jane Austen', 'all': 'Pride and Prejudice by Jane Austen (1340)', 'count': '1340'}
# Pride and Prejudice by Jane Austen (1340)
# Pride and Prejudice by Jane Austen
# 1340

# %% [markdown]
# ### 4.2 Authentication

# %% [markdown]
# The requests module can handle some forms of authentication, i.e. logins, but it requires more coding than we can get into in this workshop. I refer you to the [documentation](http://docs.python-requests.org/en/master/user/authentication/) for guidance on this issure.

# %% [markdown]
# ### 4.3 Javascript-heavy sites

# %% [markdown]
# Some sites generate content based on user actions such as menu selections or other types of "clicks". The Python [selenium](http://selenium-python.readthedocs.io/) module can help with these types of scraping applications.
