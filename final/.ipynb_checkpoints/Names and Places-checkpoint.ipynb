# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import os

# %%
path = 'data/'
title = []
date = []
report = []

# %%
for filename in os.listdir(path):
    if filename != '.DS_Store':
        soup = BeautifulSoup(open(path + filename,encoding = "ISO-8859-1"),"lxml")
        # get header (title + date)
        letters = soup.find_all(class_="header")[0].string
        letters_split = letters.split(' ')
        date_ = letters_split[-1]
        title_ = ' '.join([i for i in letters_split[:-1] if i != ''])
        # get report
        # note: I did not remove '\n' in case we will use it in the future (e.g. paragraphs).
        tables = soup.find_all("table", {"cellpadding": "10"})
        text = tables[1].findAll('td')[0].text
        text = text.replace('\xa0', '')
        title.append(title_)
        date.append(date_)
        report.append(text)

# %%
result = pd.DataFrame({'title': title, 'date':date, 'report':report})

# %%
result.head()
# Out:
#        date                                             report  \
# 0  10-10-16  \n\n\t\t\n\t\tHi Everyone ~\n\nWarm temperatur...
# 1  10-11-16  \n\n\t\t\n\t\tHi Everyone ~\n\nBig change in t...
# 2  10-12-16  \n\n\t\t\n\t\tHi Everyone ~\n\nClear sunny ski...
# 3  10-13-16  \n\n\t\t\n\t\tHi Everyone ~\n\nWell, you spend...
# 4  10-14-16  \n\n\t\t\n\t\tHi Everyone ~\n\nWell, it truly ...
#
#                                                title
# 0          Junctions, Prospects, Blacktail Prospects
# 1       Prospect Peak, ? Wolves in Hayden, grizzlies
# 2      Canyons, Prospect, Junctions, Wapiti, ?wolves
# 3  Prospect 996M Group, Junctions, Prospect Black...
# 4                              Lamar Canyon, grizzly

# %%
#The one that DOES NOT work

import nltk.data, nltk.tag

from nltk.tag.perceptron import PerceptronTagger

from nltk.corpus import brown

patterns = [
    
#     (r'.*ing$','VBG'),
#     (r'.*ed$','VBD'),
#     (r'.*es$','VBZ'),
#     (r'.*ould$','MD'),
#     (r'.*\'s$','NN$'),
#     (r'.*s$','NNS'),
#     (r'.*','NN')
    
    
    
    (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),   # cardinal numbers
         (r'(The|the|A|a|An|an)$', 'AT'),   # articles
         (r'.*able$', 'JJ'),                # adjectives
         (r'.*ness$', 'NN'),                # nouns formed from adjectives  
         (r'.*ly$', 'RB'),                  # adverbs
         (r'.*s$', 'NNS'),                  # plural nouns  
         (r'.*ing$', 'VBG'),                # gerunds   
         (r'.*ed$', 'VBD'),                 # past tense verbs
         (r'.*', 'NN')                      # nouns (default)
        
    
]

# %%
import csv

mydict = {}
reader = csv.reader(open("POS_tagging.csv", "r"))
for rows in reader:
    k = rows[0]
    v = rows[1]
    mydict[k] = v
print(mydict)
# Out:
# {'yearling': 'WLF', 'Prospects': 'WLFP', 'Junctions': 'WLFP', 'Slough': 'PLC', 'Junction Buttes': 'WLFP', 'Blacktail': 'PLC', 'Prospect': 'WLFP', '966M': 'WLF', 'pup': 'WLF', '964M': 'WLF', 'Lamar': 'PLC', 'Coyote': 'PLC', 'Name': 'Type', 'grizzly': 'BEAR'}

# %%
fd = nltk.FreqDist(brown.words())
cfd = nltk.ConditionalFreqDist(brown.tagged_words())
most_freq_words = fd.most_common(10000)
likely_tags = dict((word, cfd[word].max()) for (word, _) in most_freq_words)
#default_tagger = nltk.UnigramTagger(model=likely_tags)
#default_tagger = nltk.DefaultTagger('NN')
default_tagger = nltk.RegexpTagger(patterns)

# %%
def extract_entity_names(t):
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))          
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
    return entity_names

# %%
for entry in result['report']:
    
    entity_names = []
    
    print(entry,'...\n\n---------------------\n')
    tagged_sentences = []
    _POS_TAGGER = 'taggers/maxent_treebank_pos_tagger/english.pickle'
    sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
    sent_list = sent_detector.tokenize(entry.strip())   
    
    tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sent_list]
    
    model = mydict
    
    tagger = nltk.tag.UnigramTagger(model=model, backoff=default_tagger)
    tagged_sentences = [tagger.tag(sentence) for sentence in tokenized_sentences]
    chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)

    things = []
    places = []
    
    for sentence in tagged_sentences:
        
        for item in sentence:

            if item[1] == 'WLFP' or item[1] == 'WLF':
                things.append(item[0]) 
            
            if item[1] == 'PLC':
                places.append(item[0]) 
            
            
            
            
    
    print("Things in report:", things,"\n")
    print("Places in report:", places,"\n")

    
    for word in chunked_sentences:
        
        entity_names.extend(extract_entity_names(word)) 
        
    
    
    break
    
    
print("potential other objects and places",entity_names)
# Out:
#
# 		Hi Everyone ~
#
# Warm temperatures in the high 50's today with dark clouds and intermittent sun with a bit of a bite to the wind.
#
# Nothing in Lamar this morning with only very faint signals on 926F and 949M.
#
# Junctions ~ The story was different over at Slough where there was a great chance that we would find the Junction Buttes. We spread out from Lamar Canyon West to Crystal Creek where Pauline and I heard a distant low howl. We went to Long Pullout and Rick found the Junctions at skyline south on Specimen just over the sheep cliff. They were just all bedded there happy snappy.
#
# Mid-morning the Junctions all got up and headed east on Specimen. Calvin went to Slough to look but none of us were able to find them again.
#
# Prospect ~While standing there watching the Junctions, we could hear howling to the west on both sides of the road. It was not long before the Junctions were howling looking to the west. The Prospect wolves were on a carcass that is in the dried up pond west of Boulder in Little America. The carcass itself was out of view but we could see coyotes, eagles, ravens, and magpies. By the time we got there, the wolves had moved off of the carcass and had moved east to the north of Boulder turnout. We had alpha female 821F with her signature scar under her right eye, gray alpha male 966M who has lost his collar, 996M, the grayish black male, and 964M. Those five were howling to 2 gray pups and a black pup that we saw to the south. I am sure that they would have liked to cross but we just had too many people, so 821F crossed back over to join her pups.
#
# Later in the early afternoon, 996M and two others were seen at the carcass once more but , again, not for long before they were off to the west again. Dusty saw a gray in the Buffalo Ford and the others disappeared maybe into the Peregrines. It was 4:00, and we decided to hang up the spurs and head for the barn.
#
# Prospect Blacktail ~ Ilona did see a black in the Prospect rendezvous on the Blacktail this morning so not all the pack members were in Little America. Our count was 8 and I think that they are at 14 if they are all together.
#
# Other critters ~ Yesterday, Amy and Brad reported a beautiful bull moose in Round Prairie and another nice bull at Petrified Tree. Today, there was a black bear at Elk Creek. Lots of coyotes between the two carcasses in Lamar.
#
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Junctions', 'Junctions', 'Junctions', 'Prospect', 'Junctions', 'Junctions', 'Prospect', '966M', '964M', 'pup', 'Prospect', 'Prospect']
#
# Places in report: ['Lamar', 'Slough', 'Lamar', 'Slough', 'Blacktail', 'Blacktail', 'Lamar']
#
#
#
#
# 		Hi Everyone ~
#
# Big change in the weather especially for those at the north end of the park as they woke up to inches of snow on the ground and still a lot of blowing. All the vehicles coming from that end looked they had been through the frosty freeze. We to the Northeast, had only rain and temperatures in the 40's! Quite a change.
#
# Prospect ~ As we always say, "Feast or Famine". Today was a hard one and many, many thanks you's have to go out to Evan from the Wildside. He was at Fishermen's scanning with his clients and spotted the very last wolves disappearing into a fog bank on top the southern Divide Ridge heading to skyline. What luck! They were out of sight by the time we got there, but Rick was able to re-aquire them as they came out of the cloud and crested the top of Specimen. It was momentary as they soon all disappeared over the top and we did not see them again.
#
# We thought that they were Junctions as it was exactly in the same place they were in on 10/9. When we got a count of 12, we knew that something was a miss. Rick checked signals and got 996M which meant Prospects. Doug M. saw 763M limping along with them. We feel that there were 14 recently, but this is a time of dispersal, so maybe they are down a few.
#
# It reminded me of the time the Prospects came over in March and killed Lamar Canyon alpha male 925M. The whole family was over at that time and led by Twin, Mottled, Dark Black and 965M. I think some time in there, 821F the Prospect alpha female, wondered what they were doing out of their territory and returned quickly to their Blacktail territory.
#
# Most often the males are out to find females and the family realizes that they don't need to drag along for that!! Those Prospect males know that there is a pack with no alpha male and 4 breeding females so that instinct is guiding the whole pack at the moment.
#
# Hayden wolves ~ Amy and Brad were in Canyon and were scoping around near the Mary Mountain Trail and Amy did see a black with light gray on its belly out by the telephone poles. They also thought that they saw a gray but could not confirm.
#
# Grizzlies ~ There was a grizzly on the Boulder carcass this morning. A younger grizzly ventured into the Buffalo Ford but turned and ran up the hill when it got its sights on that big bear already on the carcass.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospect', 'Junctions', 'Prospects', 'Prospects', 'Prospect', 'Prospect']
#
# Places in report: ['Lamar', 'Blacktail']
#
#
#
#
# 		Hi Everyone ~
#
# Clear sunny skies this morning with temperatures in the teens. The sun stayed around all day with the temperatures rising to the high 40's low 50's.
#
# Canyons ~ Yesterday, 10-12-16, visitors had the Canyons in view almost the whole day a few miles from Old Faithful and Grand Prismatic. One visitors showed us lovely photos of all 6 including the white female, 712M, the gray adult female, a dark black, a gray pup, and a black pup with a lot of gray in it. There was a carcass which was pretty much gone by the end of the day. I did not get any reports of people seeing them today. At least we know that they are alive and kicking. The alphas will be 12 in April; real old timers.
#
# Prospects ~ Calvin found wolves on the carcass this morning near Boulder. The total count was 5 grays and 2 blacks. When we arrived, there was howling on both sides of the road. We went to Boulder and found Prospect 964M, a gray yearling and 996M heading to the east looking towards the road. We could not find the wolves to the south. They must have been in the trees directly south of Boulder. The three wolves did successfully cross the road and the howling stopped.
#
# Later, Bonnie from the Wildside spotted a gray way back by the tree line north of the river. We soon had alpha female 821F, alpha male 966M (missing collar), and good old 763M heading along the trail they take to Junction Lake. However, they took a turn to the north towards the Trough which is way up to the north. We lost them going into it and some went to Hellroaring to look for them to appear there. No luck there.
# At 6:20, additional wolves come in. There was a count of 10, so I guess two more had joined the party. The main one was 966M the alpha male from Prospect. He must be suspicious of this other "dominant male" we are calling Black Bar. When 966M came in Black Bar was very submissive to 966M as was 964M. Ahhhhh...things change when the big guy is in town. That is why he probably came back from the Blacktail to see what mischief his wolves were in. I do not think that Black Bar is a Prospect but maybe came in like Twin did from another pack maybe outside the park. Black Bar must know that he is not related to the females. Anyway, Big Daddy 966M came back into town to sort things out amongst is rebellious underlings.
#
# Good old 763M is relaxing on the Blacktail in his retirement years happy that he is not having to deal with such things!
#
# Junctions ~ Doug M. had them when we arrived this morning. They, too, were all sacked out. It was a while before they started to stir. The female yearling had been up and antsy for the others to move so when she saw them stirring, she returned to them to rally the troops. 907 and 969 took the lead and the others followed. We had ten; missing one gray pup. The black female yearling had her tail in the air as has been the case the last couple of months. The two female mothers, 969F and 907F, seem to have a good, strong bond. That will all change when the breeding season draws closer.
#
# When they began to travel, we had no idea how far they would go. They just kept going and going crossing the whole expanse of Antelope from the west side to the east side. Antelope is about 4.5 miles south from the Tower store. They traveled down to Antelope Creek and we thought that we had lost them but they popped up going up the slope out of the creek. They continued on and soon we had elk running everywhere with the wolves right on their heels. We had calves and cows in complete chaos. The wolves did come close to a calf and I believe I saw one making contact with a cow. We did lose them for good then as they disappeared on the heels of the elk into a gully with lots and lots of trees.
#
# Prospect Blacktail ~ Calvin and Lynette did find two blacks and a gray on their way in tonight on the Blacktail so at least some of them have made it home.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospect', 'Prospect', '964M', 'pup', 'yearling', 'yearling', 'Junctions', 'Junctions', 'pup', 'yearling', 'yearling', '964M', 'yearling', '964M', '964M', '966M', 'Prospect', '966M', '966M', '964M', 'Prospect', '966M', 'Junctions', 'yearling', 'pup', 'yearling', 'Prospect']
#
# Places in report: ['Lamar', 'Slough', 'Lamar', 'Blacktail', 'Blacktail', 'Blacktail', 'Blacktail']
#
#
#
#
# 		Hi Everyone ~
#
# Well, it truly is feast or famine. Today was tough for finding wolves. We looked from Coyote Overlook to Little America, to Antelope to Hellroaring and the Blacktail. The winds were whipping but at least the temperatures were mild in the fifties. It was actually a bit strange. We had a thick cloud cover and it did start to rain midmorning picking up later in the day. Hayden Valley had very strong winds and rain. No reported sightings there.
#
# We had some hope at Antelope but anticipation dimmed as the morning moved on. Those Prospects and Junctions were giving us the slip.
#
# There was some success much later in the day at Round Prairie where the Lamar Canyons were found now with an extra black male bringing their total to 5 black wolves, 3 males and 2 females. Not in sight very long, but just enough time to see that there was a big jet black extra male. 926F was leading all the way as they made their way to the east in the Prairie. It was raining pretty hard by then. 949M was bringing up the rear as he has acquired a limp. All of them looked very healthy. When I saw them last, the two females were scratching so hope the ravages of mange does not come back to them. It sometimes will reoccur in the winter.
#
# Pauline found a grizzly much to the delight of many visitors. It was just below the K Meadow visible from Hitching Post, Footbridge and Confluence.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospects', 'Junctions']
#
# Places in report: ['Coyote', 'Blacktail', 'Lamar']
#
#
#
#
# 		Hi Everyone ~
#
# From Doug ~ Another rainy night bringing rocks and gravel onto the road in the traditional spots.
#
# Prospects ~ Heading straight to the east, we started looking from all pointsin Little America. Larry and Linda were at Boulder making the first spot with 2 blacks on the ridge just below the high point on Specimen well to their east. Jim H. had gone to a vantage point near Longs when he heard a group howl to the south west. From Slough and Bob's Knob we were able to see 7 wolves at skyline back to the west just above 9's den meadow. These were the Prospects. They spent most of an hour mainly bedded in that area with the typical getting up, stretching and plunking back down. We had howling coming from the east. From Laurie ~ A this point they had 11 in view.
#
# Finally, feeling a bit of motivation to perhaps move to the east to check out the answers to their howls. For the most part, they stayed on the skyline. Moving to thewest to perhaps get a closer look we were able to pick them up continuing to the east mostly in view. They stalled out just before making it to the trail going up Specimen from the Crystal lot. Sitting at the skyline and looking to the east all of a sudden tails went flying in the air and the wolves charged to the east. Having to move to Slough to see where they ended up.
#
# There were reports of perhaps another pack further to the east, but it appears they were just having a bit of trouble recognizing more of their own pack. As we counted greys and blacks and collars it became evident we had more blacks than normal. As the grey pups were playing back in the sage there were two blacks on the closer side of the wolves that were pups! After a considerable time where we thought the black pups were perhaps no longer with us, there they were looking fat and sassy. Wherever they have been and whoever they were with they have done well.
#
# From Lynette and Calvin later in the day ~ The Prospects were sleeping and a cow elk started down Specimen Trail above them taking lots of time looking down. The cow elk finally got down to a point where the Prospects got interested. The wolves did move her to the trees west of the trail. They moved east below the ridge and bedded again. We went in when they were flat out.
#
# From Laurie ~ Doug is fairly certain that he saw 821F but others think that she was not there. I hope that Doug is right.
#
# Lamars ~ There were early indications the Lamars may have been around to the east but not promising enough to search diligently for them. With Dunraven closed, we couldn't look for the Junctions from Antelope.
#
# Joellyn B. found a grizzly earlier in the morning out toward the Chalcedony fan. No reports from the south and Dunraven was still closed as I headed back to the west.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospects', 'Prospects', 'Prospects', 'Prospects', 'Junctions']
#
# Places in report: ['Slough', 'Slough']
#
#
#
#
# 		Hi Everyone ~
#
# Weather today was a bit of a factor especially in Hayden Valley. Melba went clear to Geyser Basin in basically snow and wind like traveling in a snow globe. Natalie also ventured down with no sightings either.
#
# It was a tough day for finding wolves. Nothing with the Lamars and a slight hope with 996 but nothing until a black was spotted by a visitor in the Slough Creek area north of the road from Aspen. Calvin, Lynette and others did see it but lost it quickly and they could not find it again. It was like the sage just swallowed it up. They looked for a couple of hours with no luck. It could have been a pup from one of the packs. We think that they are traveling around a lot.
#
# Yesterday, it is thought by some that the 3 wolves to the east of the Prospects were actually Junction pups that were away from the pack. They seemed to run from the Prospects instead of going to them. It is thought that one year we lost some Junction pups just due to them wandering off and not being able to find their pack. That could be the case here.
#
# Later in the day, Rick did spot a gray just west of the talus outcropping north of Fishermen's. It did have a collar and he was getting his signal so most likely him. There were no other wolves seen with him. He was howling so maybe he was looking for the black that was seen earlier in the day!
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['pup', 'Prospects', 'Prospects']
#
# Places in report: ['Slough']
#
#
#
#
# 		Hi Everyone ~
#
# From Doug ~ It was snowing fairly hard this morning making visibility a problem. No indications of wolves at all was yet another problem so we were scattered from Footbridge to Elk Creek. I spent a lot of time at Lamar Canyon West with lots of interesting activity in view but no wolves. There was a very large herd of elk out in the flats below the Marge Simpson Tree and later in the morning they started up the pass single file.
#
# Later in the morning I had moved to Lower Hellroaring and there were hundreds and hundreds of elk out on Hellroaring slope with the bulls working over time keeping their harems together and their rivals at bay. From Laurie ~ This is the late breeding period for the elk.
#
# Junctions ~ From Laurie ~ Finally, they did find some wolves today thanks to the report of wolves from a guide from Jackson. He had them up by the Tower Store on the ridge to the east. Later, folks like Jim B. and others did see 3 blacks and 2 grays, most likely Junction wolves. Later in the morning, some of the Junctions were seen from the Curve Lot in Little America by visitors. This evening, Junction 969 was very loud from Coyote Overlook but despite looking long and hard for her, they were not able to spot them. 994M was not with them. I am thinking that he is dispersing, and Rick said that that will make it easier for the Prospect males to come in.
#
# Canyons ~ From Fay and Dale B. We came in through the West Entrance. We couldn't get to Hayden (roads closed due to snow)so we went as far as Old Faithful. On our way outbefore reachingMadison Junction and just crossing over the bridge overthe Gibbon River, we saw birds and a coyote out in the meadow. A couple from PA saw a white flash come out of the ditch in the distance at 5:30 PM, and we saw an Aussie's photo of the White Canyon alpha female (she was seen carrying a chunk!) At 5:45, out of the ditch (the part of the river that you couldn't see) came 712M carrying a smallish ribcage, possibly a deer.  Also saw very briefly a darker gray wolf with them, also seen carrying a chunk. They had forded the river and headed east into the trees.
# Grizzly ~ A grizzly was seen on Specimen Ridge from Elk Creek. It was a long way out there looking at the top of Specimen.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Junctions', 'Junctions', 'Prospect']
#
# Places in report: ['Lamar', 'Coyote']
#
#
#
#
# 		Hi Everyone ~
#
# It was a very pleasant day in the park with the moon looming large in the sky until late morning.
#
# Grizzly ~ We had something to look for in the Lamar and it became focused around the Ranch. I was at Hubbard Hill where we had a group of elk bunched with their bull at skyline. They were focused and paying close attention to something below them. It turned out to be a grizzly that made its way up the hill just to the east of the elk where it also made the skyline.
#
# Junctions ~ From well to the east the Junctions were spotted well above where the old bison carcass was on Ranger Hill. We had a great view from Hubbard Hill but if you were much closer they were just over the rise and out of sight. A black pup was the first to stir. She as we were soon to discover was waddling rather than walking. Full as can be and not moving very fast. Others stirred and eventually got up and also worked their way slowly up the hill to the north. Not making it over the top but bedding once again they had a grey come from the direction they were heading and that brought our total to 4 or 5 greys and 3 blacks. All three blacks were pups, 969F and 907F were amongst the greys that included two pups and perhaps the red faced grey that joined them was also a pup. Yes.... they have a carcass most likely taken some time during the night. From further to the east there was a report of a grizzly tugging on a carcass briefly in the area where the wolves were.
#
# The wolves advanced further to the north without much ambition and the greys bedded once again in view while the blacks made their way further north and east out of view from out vantage point. We had retreated to Picnic and out to the bank above the river to keep an eye on them. 969F remained in view and was occasionally joined by other greys that were most likely bedded just over the ridge and out of view. 907F joined her sister as the two of them became the hub for occasional visits from the other greys. No dominance was shown by either of them. I left with them still in view.
#
# Calvin and Lynette arrived just as everyone else was leaving ~ We had 3 blacks and 4 greys bedded on a lower ridge east side of Ranger Hill. We started loosing them heading behind a ridge. Calvin found them again farther to the east, and then lost them in heavy sage.
# We drove to YES dirt lot, just east of the Ranch, to look. I finally found them between tree tops lower. Calvin then got a count of 4 blacks. We had them milling around between two rows of trees. They headed west behind Ranger hill around 12:20. We left at 3:30 without ever seeing them again.
# Calvin and Lynette looked from Elk Creek and Blacktail today and found nothing.
# Canyons down south from Dale and Fay ~ Heard the Canyons at 7 AM. There was a great howling session, but never saw them; just a coyote messing with the hide. At 7 PM the same coyote returned and was messing with the hide, again ! Got through finally to Hayden Valley which had poor visibility. No sign of 755 or Wapiti anywhere. Maybe the weather will change soon.
# Back to Doug ~ Dunraven remained closed this morning and the road from Norris to Canyon was also closed so getting around in the southern part of the park was difficult unless you wanted to see Old Faithful!
#
# Heading to the west I stopped again to take in the hundreds and hundreds of elk visible from Hellroaring. Its wonderful to see them doing so well as we approach another winter season. Nothing from the Blacktail again today.
#
# Grizzly ~ From guide Cara McGary ~ On my evening tour, we had a nice big grizzly across Soda Butte Creek from Soda Butte Cone. I did not have any wolf sightings, but it does seem that there is a carcass to the south of the western trailhead for Specimen Ridge, just as you come into Little America. There were several juvenile bald eagles and golden eagles feeding there.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Junctions', 'Junctions', 'pup', 'pup']
#
# Places in report: ['Lamar', 'Blacktail', 'Blacktail']
#
#
#
#
# 		Hi Everyone ~
#
# From Doug ~ By the time we turned east in Mammoth you could see snow in the headlights. Further to the east there were areas where snow was sticking to the road. Winter is on the way!
#
# To the east there was enough snow to be able to see tracks in the snow on the road. At Soda Butte Picnic there were wolf and grizzly tracks but no sightings.
#
# Lots of looking without direction as there were no indications of wolves anywhere. I searched yesterdays area where we had sightings but nothing today. From Hubbard Hill we looked far to the east and as far west as we could reach.
#
# There were a large number of elk coming in from the Cache Valley and many elk on Norris. Maybe the Mollies will be following the elk. We had another group of elk passing through just north of Hubbard Hill as we did yesterday.
#
# Lots of people were at Curve where Cara's carcass sighting was yesterday. There was a grizzly leaving the area heading to the east.
#
# Looking from Elk Creek we couldn't find anything from Junction Lake to the back side of Specimen Ridge. On to Hellroaring where the numbers of elk and bison are wonderful. When the wolves catch on to the location of this vast number of elk, I think we will have some good wolf watching even though it's mostly at a long distant at Hellroaring. More snow though, and they will be easier to spot.
#
# We looked from the Nature Trail on the way in and nothing on the Blacktail.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: []
#
# Places in report: ['Blacktail']
#
#
#
#
# 		Hi Everyone ~
#
# From Doug ~ I knew the day was going to be good from the very early sightings I had. I haven't seen a pine martin since my time in Silver Gate, and this morning I had one cross the road near Lava Creek. Just a couple of miles later it was a fox that crossed the road, and then a beautiful mule deer buck. Great drive and as it started to get light out we were looking for the Lamars from Geriatric above Confluence.
#
# Lamar Canyon ~ Josh A. reported a grizzly on a carcass just east of Footbridge. Slowly the interest in finding the Lamars south of Confluence waned and people started heading east. I didn't get there in time to see the grizzly on the carcass on the south bank of Soda Butte Creek but got photos as it passed behind the trees east of Dead Puppy Hill. Hmmm, a carcass and a grizzly, this was a better place to be looking for the Lamars.
#
# A bit later we got a break as I heard a howl directly south of the eastern turn. Lots of eyes looking from everywhere from Soda Butte Cone to Footbridge and Jim B. is the one who struck gold! He found 3 of the Lamars up in the trees east of Dead Puppy and you could only see them from Jim's vantage point near the apex of the curve in the road. 926F was bedded in an area affording the best view with 949M higher up the hill with another black straight above 926F. There was very little movement. I was taking a video when 926F got up and did a quick turn around before plunking down again. She was quite full. One of the blacks made its way to the left to eat some snow before heading back to its bedding place.

#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Junctions', 'Junctions', 'pup', 'Junctions', 'pup', 'Prospects', 'pup', 'pup', 'pup', 'yearling', 'pup', 'Prospects']
#
# Places in report: ['Lamar']
#
#
#
#
# 		Hi Everyone ~
#
# ...
#
# Lots of up down and turn around. They eventually moved left and out of our sight. They were very low so we were not able to pick them up again. Before leaving, I did see a black way up slope. Three elk had their eyes on it as it followed the tree line up. Eventually, it, too, went into the trees.
#
# We left there about 3:00 or so to head back to Lamar. So our total on Prospects today in both locations would be 10.
#
# Grizzlies ~ We had two grizzlies at the carcass area at Hellroaring today. Bill also found a nice blonde grizzly on the Ski Slope south in the Lamar. We traveled down to Picnic looking for Lamars and Rick picked up another big grizzly in the big fan.
#
# Nothing in Hayden today. It was foggy until 11:00 including the Gibbon Meadow area. The road closes on Monday morning at 8:00 so everyone is getting in as much time as they can.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospects', 'Prospects', 'Prospects', 'Prospects', 'yearling', 'Prospect', 'pup', 'Prospects', 'Prospects', '966M', 'yearling', 'Prospects']
#
# Places in report: ['Lamar', 'Lamar', 'Lamar', 'Lamar', 'Lamar', 'Lamar']
#
#
#
#
# 		Hi Everyone ~
#
# Another beautiful day. Sunshine in the forecast for the next week at Northeast. Nice and toasty by afternoon.
#
# We sailed right through Lamar with not a wolf in sight. The Lamars were there last night but we could not find them and then this morning not even a possibility.
#
# Prospect main pack ~ Luckily, Jeremy found a black at Hellroaring, and then as is often the case, they began to pop up all over with a flush of ravens right next to them. A nice fresh carcass with plenty to go around. As is true so much of the time, the carcass was not in sight. The bellies also told the tale.
#
# We had a total of 10; 6 grays and 4 blacks. The grays included alpha male 966M, 2 gray pups, 2 gray female yearlings and alpha female 821F. The blacks included 996M and three others we could not identify because of the distance. The normal count for Prospect is 13 so we were missing a few. 763M was not there again today. Hopefully he is with the others.
#
# They did not stay around the carcass long. It was hoist anchor and be on your way time. They started climbing the Hellroaring slope at a reasonable pace with the pups playing hard along the way. The sight of them tends to bunch up the elk, but with full bellies, they just continued on their way. Loads and loads of elk can be seen all over there, so a very reasonable place for wolves to be. The sun was in our eyes and the sage was thick so following them was not easy. One of the female yearlings was very aggressive to the other pinning her many times. This is not unusual for sisters in a wolf pack trying to get the pecking order worked out. They eventually reached a small sage covered hill and bedded on it.
#
# Bill and others were there later in the day and there was not much more activity.
#
# Prospect 964M and a black ~ Some visitors saw a gray collared wolf sitting near the road near Fishermen's. An uncollared wolf was seen with it around 10:00 this morning. We were lucky to catch up with them at Slough and they had photos. It was 964M and probably the missing black from the main Prospect Pack back at Hellroaring. They said he crossed to the north and headed on up to Secret Passage. He would be the missing gray from Prospect and the black is probably one of the 2 blacks missing from the group we had this morning.
#
# I know that it is difficult to follow but Junction and Prospect are just in chaos at the moment. Everyday is a new day and a new count!
#
# Here is who should be in the Prospect Peak Pack 13 7 grays and 6 blacks ~ Alphas 966M, 821F, black yearling 996M, 763M former alpha that is black but graying all over, gray adult 964M, dark throated gray female yearling, lighter gray female yearling, Black Bar that is a grizzled gray color with a white bar on his chest, black female yearling Halter Bar with two white triangles on her chest, black yearling Small Dot for the small white dot on his chest , 2 gray pups and 1 black pup.
#
# Junction Butte Pack should number 11 with 7 grays and 4 blacks ~  907F, 969F, 3 gray pups, 1 gray female yearling, 3 black pups, black female yearling, and 994M gray male yearling. We know that 994M is moving around in the Hellroaring area because of his collar. There have been no sightings, however. The last group we saw together was 907F, 969F, 3 gray pups and the gray female yearling. I am hoping that the black pups and female yearling are with 994M.  We just don't know.
#
# Wapitis ~ We arrived to the fog lifting in Hayden. We stopped to scope Alum East and West. Our next stop was Grizzly Overlook and othersspread out. I asked Warren to please go to Trout Creek.Warren and Julie climbed the eastern hill first. At 9:45AMthey quickly called me to come as they had 5 of the 9 Wapitis in view. We soon had acquired all 9 of them.
#
# Some were bedded and moving around to find another place to rest in the sun. Thirty-fiveminutes later the yearling female was first to stand up to move right followed by the alpha female, next 1014M and the rest of the pack members. We watched them head into the trees and out of sight.
#
# Around 11:00 AMKaren E. let us know she could see them from the 3 Panel Pullout on the east side. At this sighting, we watched them not only scent mark but they were sniffing around to see if there were any unfamiliar scents.
#
# A coyote came into view, and as soon as the alpha female saw it she raceddown the hill with the rest of the pack following behind her.The coyote ran for its life and was quickly out of the area. Again they traveled south and out of sight in the trees.
#
# Weheaded to Nez Perce to wait for them. After sometime, we left to head back north. We were lucky to find them againfrom the pullout north ofMud Volcano. Here they wereon the other side of the Yellowstone River. The whole pack, especially the pups, were eyeing a bison herd. A big bull charged the alpha female sending her running off. Amazingly one of the gray pups sat directly behind the bull bison. The black pup and an adult black sat to the left of the bison. At one point the whole packwas in a circle around the bison. They milled around each other and then gathered together as a group with some moving left to right and some right to left
#
# While watching the pack we saw 5 hikers on the trail above the them. We do not think the hikers saw them, but the pack seemed to know they were there. They began to travel south again and out of our sight.
#
# This was our last sighting for the day that began at 9:45AMand ended at around 1:00PM.
#
# Grizzlies ~ 5 grizzlies today. There was a grizzly around the Prospect carcass this morning but the wolves were able to chase it away. Later in the day Bill and Kim K. did see the sow and coy back in Little America. Bill also had one in Lamar, and one by Boulder Lake.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospect', '966M', 'Prospect', 'Prospect', '964M', '964M', 'Prospect', 'Prospect', 'Prospect', 'Prospect', '966M', 'yearling', '964M', 'yearling', 'yearling', 'yearling', 'yearling', 'pup', 'yearling', 'yearling', 'yearling', 'yearling', 'yearling', 'yearling', 'pup', 'Prospect']
#
# Places in report: ['Lamar', 'Slough', 'Lamar']
#
#
#
#
# 		Hi Everyone ~
#
# It was yet another gorgeous day in the Park with 43 degrees in Mammoth at 10:00.
#
# ? wolves ~ This morning visitors reported having 3 blacks and 3 grays in the Slough den area last evening. Hard to tell who they were. Junction 969F is in about the same place she was yesterday, so we are thinking it is not the Junctions. We looked for 969F from Blacktail out towards Prospect Peak but had no luck in finding her.
#
# Prospect ~ Bill, once again, had spotted a bear AND wolves from Hellroaring. When I arrived the Prospects were up and moving to the west. All of a sudden, they encountered elk and the chase was on in many directions. Those trees at that pullout are so troublesome. We were all running around trying to see. I finally got a spot where I could see the chase as the elk zig-zagged back and forth with the wolves right on her. She ran to Hellroaring Creek and with a splash hit the water. The wolves were not daunted and went in right after her. She looked like she was going deeper but then got out on the other side. The wolves were on her again so back into the water she went. She moved toward the old bison carcass the bears have been on. It is very shallow there. A collared gray, we think 821F, on one side of the elk made contact at the neck with others at the rear end. She held onto the neck for a good while but the elk managed to break free but slipped on the rocks in the shallow water which ended up being the final blow. She was not able to recover from that and 821F was, again, on her throat and it was over. It was maybe 8 minutes from first initial attack to the end.
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Junctions', 'Prospect', 'Prospect', 'Prospects', '966M', 'yearling', '966M', '966M', '964M', '964M', 'pup', 'pup', 'Prospects']
#
# Places in report: ['Slough', 'Blacktail']
#
#
#
#
# 		Hi Everyone ~
#
# Well, the lovely weather just keeps rolling along. We had highs in the mid 50's today with 56 degrees at Northeast this afternoon.
#
# We had a beautiful morning with the Prospects. Luckily for us, Bob L. is on the Northern Range. We were all spread out looking for wolves from Lamar to Hellroaring. Bob went out on Bob's spot glassing the Slough flats and ridges all around. He was able to spot the Prospect wolves in the saddle of the ridge. They headed straight down to the flats, we lost for a bit, and then picked back up by Jeff A. from Dave's Hill heading east along the creek and were settling in at the bottom of the Lion Meadow.
#
# By the time we got there, they had just about settled. We had 6 grays including 966M, 821M, 964M, 2 gray pups, one female yearling. This dark throated yearling was pinning and making the life of the other female yearling so intolerable, the other female yearling may have just taken a break from the pack. The blacks included 996M, Black Bar, Halter Bar, Small Dot, and the black pup. His leg was much better today.
#
# They were just moving along happy, snappy. Those pups don't let up. They are taking advantage of their young age while the adults are all flopped out sleeping. Lots of antlers and buffalo wallows perfect for the young pups. Live it up while you can. Halter Bar kept her distance from 821F. 964M kept his distance while staying a part of the family.
#
# We had them for a good two hours as they slept and then made their way to the Yellow Grass Meadow and out of sight. Lots and lots of smiles from happy visitors.
#
# There were two grizzlies visiting Hellroaring near the carcass this morning.
#
# I saw an ermine near Slough today. He is waiting for the snow because at this juncture he sticks out like a sore thumb!
#
# Until tomorrow,
# Laurie
# yellowstonereports.com
# Please do not forward, post,
# paraphrase, publish in any
# form, or copy for distribution
# Laurie Lyman Copyright 2016
#  ...
#
# ---------------------
#
# Things in report: ['Prospects', 'Prospect', '966M', '964M', 'yearling', 'yearling', 'yearling', 'yearling', 'pup', '964M']
#
# Places in report: ['Lamar', 'Slough', 'Slough']
#
# potential other objects and places []

# %% [markdown]
# ### import nltk
#
# sentence = "At eight o'clock on Thursday film morning word line test best beautiful Ram Aaron design"
#
# tokens = nltk.word_tokenize(sentence)
#
# tagged = nltk.pos_tag(tokens)
#
# print(tagged)
# length = len(tagged) - 1
#
# a = list()
#
# for item in tagged:
#     if item[1][0] == 'N':
#       a.append(item[0])
#
# print(a)

# %%
_POS_TAGGER = 'taggers/maxent_treebank_pos_tagger/english.pickle'
default_tagger = nltk.data.load(_POS_TAGGER)
model = {'Hi': 'VB'}
tagger = nltk.tag.UnigramTagger(model=model, backoff=default_tagger)

# %%
#The one that works

import nltk.data, nltk.tag

from nltk.tag.perceptron import PerceptronTagger
class BackoffTagger:
    def __init__(self):
        self._taggers = [PerceptronTagger()]

entity_names = []

for entry in result['report']:
    tagged_sentences = []
    
    sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
    sent_list = sent_detector.tokenize(text.strip())   
    
    tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sent_list]
    

    tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]

    
    chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)
    
    for word in chunked_sentences:
        print(word)
        entity_names.extend(extract_entity_names(word)) 
    break
