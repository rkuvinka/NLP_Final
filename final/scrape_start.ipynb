# %%
import requests
from bs4 import BeautifulSoup
import re
import time

# %%
dateRange = range(111,112)


for date in dateRange:
    soup = BeautifulSoup(open('{0}.html'.format(str(date)),encoding = "ISO-8859-1"),"lxml")
    titleTag = soup.html.head.title
    print (titleTag.string)
# Out:
#  Yellowstone Reports

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Yellowstone Reports
#   </title>
#   <link href="styles.css" rel="stylesheet"/>
#   <style type="text/css">
#    .slideshow { height: 100px; width: 800px }
# 		.slideshow img { padding: 0px; border: 0px solid #000; }
#   </style>
#   <script src="https://www.google.com/recaptcha/api.js">
#   </script>
#  </head>
#  <!-- <SCRIPT TYPE="text/javascript" src="jquery-1.3.2.min.js"></SCRIPT> -->
#  <!-- <SCRIPT TYPE="text/javascript" src="/reflection.js"></SCRIPT> -->
#  <script src="/jquery-1.4.js" type="text/javascript">
#  </script>
#  <script src="jquery.blockUI.js" type="text/javascript">
#  </script>
#  <script src="/jquery.cycle.all.2.72.js" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   //http://malsup.com/jquery/block/#page
# $(function($) {
#
# 	// unblock when ajax activity stops
# 	$().ajaxStop($.unblockUI);
#
# 	//function test() {
# 	//	$.ajax({ url: 'about-oconnells-nature-prints.php', cache: false });
# 	//}
#
# 	$(document).ready(function() {
# 		$('#stall').click(function() {
# 			$.blockUI({ message: '<BR><SPAN STYLE="font: 12pt verdana, arial, sans-serif; color: #664400; font-weight: bold">Processing payment...please wait</SPAN><BR><BR>' });
# 			//test();
# 		});
#
#
#     $('.slideshow').cycle({
#      		// choose your transition type, ex: fade, scrollUp, shuffle, etc...
# 		fx: 'fade',
#     		speed:  4200
# 	});
#
# 	});
#
# });
#
#
#
# function jumpPage(newLoc) {
# 	newPage = newLoc.options[newLoc.selectedIndex].value;
# 	if ( newPage != "" ) {
# 		location.href = newPage;
# 	}
# }
#  </script>
#  <body background="images/brown_backer.gif" bgcolor="#FFFFFF" leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
#   <table background="images/brown_backer.gif" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <img height="1" src="images/spacer.gif" width="1"/>
#        </td>
#       </tr>
#      </table>
#      <table border="0" cellpadding="0" cellspacing="0" width="1028">
#       <tr valign="top">
#        <td width="446">
#         <img height="56" src="images/yellowstone_report.gif" width="446"/>
#        </td>
#        <td align="right" style="font-size:8pt; font-weight:bold; color:white; padding-top:5px; padding-right:5px;">
#         Produced by The Wild Side LLC
#        </td>
#       </tr>
#      </table>
#      <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <img height="1" src="images/spacer.gif" width="1"/>
#        </td>
#       </tr>
#      </table>
#      <!-- http://www.malsup.com/jquery/cycle/ -->
#      <table background="images/brown_backer.gif" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <div class="slideshow" id="rotater" style="display:none">
#          <img height="100" src="images/banners/103.jpg" width="1028"/>
#          <img height="100" src="images/banners/95.jpg" width="1028"/>
#          <img height="100" src="images/banners/50.jpg" width="1028"/>
#          <img height="100" src="images/banners/101.jpg" width="1028"/>
#          <img height="100" src="images/banners/102.jpg" width="1028"/>
#          <img height="100" src="images/banners/106.jpg" width="1028"/>
#          <img height="100" src="images/banners/98.jpg" width="1028"/>
#          <img height="100" src="images/banners/49.jpg" width="1028"/>
#          <img height="100" src="images/banners/46.jpg" width="1028"/>
#          <img height="100" src="images/banners/93.jpg" width="1028"/>
#          <img height="100" src="images/banners/55.jpg" width="1028"/>
#          <img height="100" src="images/banners/92.jpg" width="1028"/>
#          <img height="100" src="images/banners/104.jpg" width="1028"/>
#          <img height="100" src="images/banners/58.jpg" width="1028"/>
#          <img height="100" src="images/banners/94.jpg" width="1028"/>
#          <img height="100" src="images/banners/82.jpg" width="1028"/>
#          <img height="100" src="images/banners/100.jpg" width="1028"/>
#          <img height="100" src="images/banners/74.jpg" width="1028"/>
#          <img height="100" src="images/banners/111.jpg" width="1028"/>
#          <img height="100" src="images/banners/99.jpg" width="1028"/>
#          <img height="100" src="images/banners/54.jpg" width="1028"/>
#          <img height="100" src="images/banners/63.jpg" width="1028"/>
#          <img height="100" src="images/banners/110.jpg" width="1028"/>
#          <img height="100" src="images/banners/109.jpg" width="1028"/>
#          <img height="100" src="images/banners/59.jpg" width="1028"/>
#          <img height="100" src="images/banners/107.jpg" width="1028"/>
#          <img height="100" src="images/banners/91.jpg" width="1028"/>
#          <img height="100" src="images/banners/81.jpg" width="1028"/>
#          <img height="100" src="images/banners/89.jpg" width="1028"/>
#          <img height="100" src="images/banners/108.jpg" width="1028"/>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <img height="1" src="images/spacer.gif" width="1"/>
#     </td>
#    </tr>
#   </table>
#   <table bgcolor="#006600" border="0" cellpadding="3" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <table border="0" cellpadding="0" cellspacing="0" width="1020">
#       <tr>
#        <form action="/login.php" method="post">
#         <td width="30">
#          <img height="16" src="images/spacer.gif" width="30"/>
#         </td>
#         <td bgcolor="#006600">
#          <span class="nav">
#           <a href="index.php">
#            Home
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="search.php">
#            Reports
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="reporters.php">
#            The reporters:
#           </a>
#          </span>
#          <select class="drop_down" name="select_list" onchange="jumpPage(this.form.select_list);" style="font-size: 8pt; width:150px">
#           <option value="">
#            Choose ...
#           </option>
#           <option value="search.php?action=search&amp;author_id=7&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Editor of Yellowstone Reports
#           </option>
#           <option value="search.php?action=search&amp;author_id=18&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Rick Lamplugh
#           </option>
#           <option value="search.php?action=search&amp;author_id=19&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Sandy Sisti
#           </option>
#           <option value="search.php?action=search&amp;author_id=21&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Jimmy Jones
#           </option>
#           <option value="search.php?action=search&amp;author_id=22&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Russ Kehler
#           </option>
#           <option value="search.php?action=search&amp;author_id=5&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Laurie Lyman
#           </option>
#           <option value="search.php?action=search&amp;author_id=12&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Michael Leach
#           </option>
#           <option value="search.php?action=search&amp;author_id=14&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Leo Leckie
#           </option>
#           <option value="search.php?action=search&amp;author_id=17&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Ilona Popper
#           </option>
#           <option value="search.php?action=search&amp;author_id=9&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Dave Hornoff
#           </option>
#           <option value="search.php?action=search&amp;author_id=4&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Dan Hartman
#           </option>
#           <option value="search.php?action=search&amp;author_id=1&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Dr. Nathan Varley
#           </option>
#           <option value="search.php?action=search&amp;author_id=6&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Linda Thurston
#           </option>
#           <option value="search.php?action=search&amp;author_id=2&amp;start_year=2002&amp;start_month=01&amp;start_day=01&amp;end_year=2016&amp;end_month=11&amp;end_day=08">
#            Mike O'Connell
#           </option>
#          </select>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="account.php">
#            My account
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="about-yellowstone-reports.php">
#            About us
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="contact.php">
#            Contact us
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="faqs-yellowstone-reports.php">
#            FAQs/Help
#           </a>
#          </span>
#          <span style="color:white">
#           |
#          </span>
#          <span class="nav">
#           <a href="login.php?logout=1">
#            Logout
#           </a>
#          </span>
#         </td>
#        </form>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <img height="1" src="images/spacer.gif" width="1"/>
#     </td>
#    </tr>
#   </table>
#   <table bgcolor="FFFFE9" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <table bgcolor="FFFFE9" border="0" cellpadding="0" cellspacing="0" width="1020">
#       <tr>
#        <td align="RIGHT">
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <table bgcolor="FFFFE9" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td>
#      <table bgcolor="FFFFE9" border="0" cellpadding="0" cellspacing="0" width="770">
#       <tr valign="TOP">
#        <td width="20">
#         <img height="600" src="images/spacer.gif" width="20"/>
#        </td>
#        <td width="750">
#         <br/>
#         <!-- <FORM><DIV ALIGN=RIGHT><INPUT TYPE="button" VALUE="Close window" onClick="window.close()"></DIV></FORM> -->
#         <script type="text/JavaScript">
#          //courtesy of BoogieJack.com
# function killCopy(e){
# 	return false
# }
# function reEnable(){
# 	return true
# }
# document.onselectstart=new Function ("return false")
# if (window.sidebar){
# 	document.onmousedown=killCopy
# 	document.onclick=reEnable
# }
#         </script>
#         <!-- <DIV ALIGN=RIGHT> -->
#         <table border="0" cellpadding="0" cellspacing="0" width="100%">
#          <tr valign="TOP">
#           <td>
#            <table bgcolor="#CCCCCC" border="0" cellpadding="1" cellspacing="0">
#             <tr>
#              <td>
#               <table bgcolor="#FFFFD5" border="0" cellpadding="3" cellspacing="0" height="24">
#                <tr>
#                 <td>
#                  <a href="index.php">
#                   <img border="0" height="16" src="images/arrow_rotate_clockwise.png" width="16"/>
#                  </a>
#                 </td>
#                 <td>
#                  <nobr>
#                   <span class="pf">
#                    <a href="index.php">
#                     Return home
#                    </a>
#                   </span>
#                  </nobr>
#                 </td>
#                </tr>
#               </table>
#              </td>
#             </tr>
#            </table>
#           </td>
#           <td align="RIGHT">
#            <table bgcolor="#CCCCCC" border="0" cellpadding="1" cellspacing="0">
#             <tr>
#              <td>
#               <table bgcolor="#FFFFD5" border="0" cellpadding="3" cellspacing="0" height="24">
#                <tr>
#                 <td>
#                 </td>
#                 <td>
#                  <nobr>
#                   <span class="pf">
#                    No printer-friendly version for this reporter
#                   </span>
#                  </nobr>
#                 </td>
#                </tr>
#               </table>
#              </td>
#             </tr>
#            </table>
#           </td>
#          </tr>
#         </table>
#         <!-- </DIV> -->
#         <img height="7" src="images/spacer.gif" width="1"/>
#         <br/>
#         <table bgcolor="#CCCCCC" border="0" cellpadding="1" cellspacing="0">
#          <tr>
#           <td>
#            <table bgcolor="#FFFFD5" border="0" cellpadding="10" cellspacing="0" width="100%">
#             <tr valign="TOP">
#              <td>
#               <b class="header">
#                Wapitis grizzlies    11-1-16
#               </b>
#               <br/>
#               <img height="7" src="images/spacer.gif" width="1"/>
#               <br/>
#               <i>
#                by Laurie Lyman
#               </i>
#              </td>
#              <td align="RIGHT">
#               <nobr>
#                <i>
#                 Nov. 1, 2016
#                </i>
#               </nobr>
#              </td>
#             </tr>
#            </table>
#            <table bgcolor="#CCCCCC" border="0" cellpadding="0" cellspacing="0" width="100%">
#             <tr>
#              <td>
#               <img height="1" src="images/spacer.gif" width="1"/>
#              </td>
#             </tr>
#            </table>
#            <table bgcolor="#FFFFFF" border="0" cellpadding="10" cellspacing="0">
#             <tr valign="TOP">
#              <td>
#               <br/>
#               Hi Everyone ~
#               <br/>
#               <br/>
#               Some reports from yesterday ~  Lamars were seen early afternoon in Soda Butte Valley by visitors.  Two blacks and a gray were seen at Hellroaring in the afternoon.
#               <br/>
#               <br/>
#               Another day of clouds, spritzes of snow, and temps in the mid 30's.  No wind making it a great day weather wise.
#               <br/>
#               <br/>
#               We looked from Soda Butte Valley to Blacktail for wolves and just did not have any luck at all.  There were very faint possibilities in Little America for Junctions and Soda Butte Valley for Lamars.
#               <br/>
#               <br/>
#               I focused my day in Little America and Soda Butte Valley.
#               <br/>
#               <br/>
#               Natalie, Melba and Karen reported Wapitis on a carcass in Hayden Valley.  Here is Karen's report ~  Dusty called and told me they had the Wapitis in Hayden Valley.  They had 5 to the west and howling to the east.  We arrived at about 8:15AM and several had scopes already up.  Right off the bat, we could see 5 Wapitis to the west on a carcass.  We saw the black pup alone to the east, near Sour Creek rendezvous.  We watched the pup and would return to the rest of the pack to the west.  After a while, the pup went to the river and looked like she was going to go to the road and cross.  But, instead, she headed into the trees and out of sight.  At about 10AM, here she came running to the carcass from the right.  We do not know where she crossed the road.
#               <br/>
#               <br/>
#               The wolves were so full with bulging bellies!!  They all bedded down, still in sight for a nice nap.  Then the snow came in and visibility was very poor.  During this little snow shower, they slipped out of sight and when we were able to see across the meadow, they were gone!  But it was an excellent morning with all 9 wolves present and accounted for!
#               <br/>
#               <br/>
#               Grizzlies ~  Still had 4 or 5 grizzlies at Hellroaring this morning.  It has been several days now so that carcass truly is the gift that just keeps on giving!!  Lots of happy people.
#               <br/>
#               <br/>
#               Until tomorrow,
#               <br/>
#               Laurie
#               <br/>
#               yellowstonereports.com
#               <br/>
#               Please do not forward, post,
#               <br/>
#               paraphrase, publish in any
#               <br/>
#               form, or copy for distribution
#               <br/>
#               Laurie Lyman Copyright 2016
#               <br/>
#              </td>
#              <td width="150">
#               <br/>
#               <table bgcolor="#006600" border="0" cellpadding="1" cellspacing="0">
#                <tr>
#                 <td>
#                  <table bgcolor="#FFFFFF" border="0" cellpadding="5" cellspacing="0">
#                   <tr>
#                    <td bgcolor="#006600">
#                     <b class="white">
#                      Photos
#                     </b>
#                     <br/>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td align="CENTER">
#                     <img height="3" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <table bgcolor="#CCCCCC" border="0" cellpadding="1" cellspacing="0" width="100%">
#                      <tr>
#                       <td>
#                        <table bgcolor="#FFFFD5" border="0" cellpadding="3" cellspacing="0" width="100%">
#                         <tr>
#                          <td width="16">
#                           <a href="JavaScript:void(0)" onclick="popup('slide_show.php?cid=4949')">
#                            <img border="0" height="16" src="images/camera.png" width="16"/>
#                           </a>
#                          </td>
#                          <td>
#                           <nobr>
#                            <span class="pf">
#                             <a href="JavaScript:void(0)" onclick="popup('slide_show.php?cid=4949')">
#                              View slide show
#                             </a>
#                            </span>
#                           </nobr>
#                          </td>
#                         </tr>
#                        </table>
#                       </td>
#                      </tr>
#                     </table>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14613&amp;img=14613.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14613_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Extraordinary elk population at Hellroaring
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14614&amp;img=14614.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14614_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Elk at Hellroaring
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14615&amp;img=14615.jpg')">
#                       <span class="pop">
#                        <img border="1" height="150" src="photos/14615_t.jpg"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti black female pup
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14616&amp;img=14616.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14616_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapitis on carcass
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14617&amp;img=14617.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14617_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Fox in Hayden Valley
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14619&amp;img=14619.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14619_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti black female pup
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14621&amp;img=14621.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14621_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14622&amp;img=14622.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14622_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapitis
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14624&amp;img=14624.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14624_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti grays
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14625&amp;img=14625.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14625_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapitis on carcass
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14626&amp;img=14626.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14626_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapitis on carcass
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14627&amp;img=14627.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14627_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14628&amp;img=14628.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14628_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14629&amp;img=14629.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14629_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti
#                     </span>
#                     <br/>
#                     <img height="7" src="images/spacer.gif" width="1"/>
#                     <br/>
#                     <span class="image">
#                      <a href="JavaScript:void(0)" onclick="popup('image_pop.php?iid=14630&amp;img=14630.jpg')">
#                       <span class="pop">
#                        <img border="1" src="photos/14630_t.jpg" width="150"/>
#                       </span>
#                      </a>
#                     </span>
#                     <div style="margin-bottom:2px;">
#                     </div>
#                     <span style="font-size:9pt;">
#                      Wapiti
#                     </span>
#                     <br/>
#                     <img height="3" src="images/spacer.gif" width="1"/>
#                     <br/>
#                    </td>
#                   </tr>
#                  </table>
#                 </td>
#                </tr>
#               </table>
#               <br/>
#              </td>
#             </tr>
#            </table>
#           </td>
#          </tr>
#         </table>
#         <br/>
#         <script language="JavaScript" type="text/javascript">
#          <!--
#
# function openWin( windowURL, windowName, windowFeatures ) {
# 	return window.open( windowURL, windowName, windowFeatures ) ;
# }
#
# function popup(url) {
# 	params  = 'width='+screen.width;
# 	params += ', height='+screen.height;
# 	params += ', top=0, left=0'
# 	params += ', fullscreen=yes';
# 	params += ', resizable=yes';
# 	params += ', scrollbars=yes';
# 	 newwin=window.open(url,'windowname4', params);
# 	if (window.focus) {
# 		newwin.focus()
# 	}
# 	return false;
# }
#
# function printer_popup(url) {
# 	var width  = 620;
# 	var height = 700;
# 	var left   = (screen.width  - width)/2;
# 	var top    = ((screen.height - height)/2) + 50;
# 	var params = 'width='+width+', height='+height;
# 	params += ', top='+top+', left='+left;
# 	params += ', directories=no';
# 	params += ', location=no';
# 	params += ', menubar=no';
# 	params += ', resizable=yes';
# 	params += ', scrollbars=yes';
# 	params += ', status=no';
# 	params += ', toolbar=no';
# 	newwin=window.open(url,'windowname5', params);
# 	if (window.focus) {
# 		newwin.focus()
# 	}
# 	return false;
# }
#
#  // -->
#         </script>
#        </td>
#       </tr>
#      </table>
#      <table bgcolor="white" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <img height="4" src="images/spacer.gif" width="1"/>
#        </td>
#       </tr>
#      </table>
#      <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <img height="1" src="images/spacer.gif" width="1"/>
#        </td>
#       </tr>
#      </table>
#      <table background="images/brown_backer.gif" border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td>
#         <table border="0" cellpadding="5" cellspacing="0" width="770">
#          <tr valign="TOP">
#           <td width="10">
#            <img height="20" src="images/spacer.gif" width="10"/>
#           </td>
#           <td width="350">
#            <img height="7" src="images/spacer.gif" width="350"/>
#            <br/>
#            <span style="font-size: 7pt; color:#FFFFFF">
#             © 2009-2016 Yellowstone Reports. All Rights Reserved.
#            </span>
#           </td>
#           <td align="RIGHT" width="350">
#            <!--
# <IMG SRC="images/spacer.gif" WIDTH="350" HEIGHT="7"><BR><SPAN STYLE="font-size: 7pt">
# <A HREF="terms.php" STYLE="color:#CCCCCC">Terms and conditions</A>
# &nbsp;&nbsp;
# <A HREF="privacy.php" STYLE="color:#CCCCCC">Privacy policy</A>
# 		</SPAN><BR><IMG SRC="images/spacer.gif" WIDTH="1" HEIGHT="36">
#  -->
#            <br/>
#           </td>
#          </tr>
#         </table>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <script type="text/javascript">
#    rotater.style.display = 'block';
#   </script>
#  </body>
# </html>

# %%
table = soup.table
print (table)
# Out:
# <table background="images/brown_backer.gif" border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
# <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td><img height="1" src="images/spacer.gif" width="1"/></td></tr></table>
# <table border="0" cellpadding="0" cellspacing="0" width="1028">
# <tr valign="top">
# <td width="446"><img height="56" src="images/yellowstone_report.gif" width="446"/></td>
# <td align="right" style="font-size:8pt; font-weight:bold; color:white; padding-top:5px; padding-right:5px;">Produced by The Wild Side LLC</td>
# </tr>
# </table>
# <table bgcolor="black" border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td><img height="1" src="images/spacer.gif" width="1"/></td></tr></table>
# <!-- http://www.malsup.com/jquery/cycle/ -->
# <table background="images/brown_backer.gif" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <div class="slideshow" id="rotater" style="display:none">
# <img height="100" src="images/banners/103.jpg" width="1028"/>
# <img height="100" src="images/banners/95.jpg" width="1028"/>
# <img height="100" src="images/banners/50.jpg" width="1028"/>
# <img height="100" src="images/banners/101.jpg" width="1028"/>
# <img height="100" src="images/banners/102.jpg" width="1028"/>
# <img height="100" src="images/banners/106.jpg" width="1028"/>
# <img height="100" src="images/banners/98.jpg" width="1028"/>
# <img height="100" src="images/banners/49.jpg" width="1028"/>
# <img height="100" src="images/banners/46.jpg" width="1028"/>
# <img height="100" src="images/banners/93.jpg" width="1028"/>
# <img height="100" src="images/banners/55.jpg" width="1028"/>
# <img height="100" src="images/banners/92.jpg" width="1028"/>
# <img height="100" src="images/banners/104.jpg" width="1028"/>
# <img height="100" src="images/banners/58.jpg" width="1028"/>
# <img height="100" src="images/banners/94.jpg" width="1028"/>
# <img height="100" src="images/banners/82.jpg" width="1028"/>
# <img height="100" src="images/banners/100.jpg" width="1028"/>
# <img height="100" src="images/banners/74.jpg" width="1028"/>
# <img height="100" src="images/banners/111.jpg" width="1028"/>
# <img height="100" src="images/banners/99.jpg" width="1028"/>
# <img height="100" src="images/banners/54.jpg" width="1028"/>
# <img height="100" src="images/banners/63.jpg" width="1028"/>
# <img height="100" src="images/banners/110.jpg" width="1028"/>
# <img height="100" src="images/banners/109.jpg" width="1028"/>
# <img height="100" src="images/banners/59.jpg" width="1028"/>
# <img height="100" src="images/banners/107.jpg" width="1028"/>
# <img height="100" src="images/banners/91.jpg" width="1028"/>
# <img height="100" src="images/banners/81.jpg" width="1028"/>
# <img height="100" src="images/banners/89.jpg" width="1028"/>
# <img height="100" src="images/banners/108.jpg" width="1028"/>
# </div>
# </td>
# </tr>
# </table>
# </td></tr></table>

# %%
titleTag = soup.html.head.title
print (titleTag.string)
# Out:
#  Yellowstone Reports

# %%
alerts = soup.find_all('td', 'I')

# %%
print(alerts)
# Out:
# []
